# %% [markdown]
#  <div>
# <img src="https://edlitera-images.s3.amazonaws.com/new_edlitera_logo.png" width="500"/>
# </div>

# %% [markdown]
# # `Word representations`

# %% [markdown]
# **Two types of models:**
#
# * **co-occurence based models** - train over the whole corpus and capture global dependencies and context
#
# * **predictive models** - train over a smaller section (**context window**) and capture local dependencies
#
# * we will mostly use predictive models (more on them in the following notebook)

# %% [markdown]
# **Two types of word representations:**
#
# * Sparse representations
#
# * Distributed representations

# %% [markdown]
# # `Sparse word representations`

# %% [markdown]
# * Bag-of-words and TFIDF are **sparse representations**
#     * to represent n different words, we require n dimensions
#     * in practice: we need as many dimensions as there are words in the dictionary of our entire corpus
#
#
# * this is called the **curse of dimensionality**
#     * since there are a lot of different words in corpora, when representing n words with n dimensions a lot of the dimensions end up being zeros
#
#
# * solution: **limit our vocabulary (limit the number of dimensions of our Vector Space Model)**
#     * words removed are called **OOV words (Out-Of-Vocabulary words)**
#     * problem: can't assign semantic meaning to OOV words
#
#
# * **additional problem**: hard to find connections between words

# %% [markdown]
# **We can solve this problem using Word Embeddings**

# %% [markdown]
# # `Distributed Representations`

# %% [markdown]
# * for Deep Learning we typically transform words into so-called **word embeddings**
#     * this allows us to represent words in a neural networks friendly way

# %% [markdown]
# * distributed representations are based on the following ideas:
#     * words used in similar contexts have similar meanings
#     * meaning can be derived by performing statistical analysis of word usage

# %% [markdown]
# * great because:
#     * can create representations for words that are NOT sparse
#     * can decrease the number of dimensions we need to represent some corpus of words

# %% [markdown]
# ## `Vector Space Model`

# %% [markdown]
# * model for representing text data as vectors in some n-dimensional space

# %% [markdown]
# * similar data will be represented with vectors of similar values
#     * this makes calculating similarities between examples easy

# %% [markdown]
# <center><img src="https://edlitera-images.s3.amazonaws.com/vector_space_model.png" width="800">
#
# inspired by:
# <br>
# https://www.researchgate.net/publication/298215705_A_Quantitative_Evalution_of_the_Enhanced_Topic-based_Vector_Space_Model

# %% [markdown]
# * vectors that are similar are closer to each other (e.g. the vector "car" is close to the vector "vehicle", but far from the vector "wave")

# %% [markdown]
# # `Word embeddings`

# %% [markdown]
# * instead of representing each word as a one-hot encoded vector we can represent words as combinations of features

# %% [markdown]
# * can create embeddings for entire documents!

# %% [markdown]
# * drastically decreases the number of values needed to represent a word

# %% [markdown]
# * results in dense representations

# %% [markdown]
# * we can also add new words without needing to add new features

# %% [markdown]
# * **IMPORTANT:** because words share the same features, we can easily deduce which words are similar to each other
#     * example: the vectors representing the words "boy" and "prince" would be closer to each other than the vectors representing "girl" and "prince"

# %% [markdown]
# ### `Word embeddings example`

# %% [markdown]
# <center><img src="https://edlitera-images.s3.amazonaws.com/dense_representation.png" width="700">
#
# source:
# <br>
# https://www.r-craft.org/r-news/get-busy-with-word-embeddings-an-introduction/

# %% [markdown]
# ## `Concept of analogies`

# %% [markdown]
# * we can add and substract embeddings

# %% [markdown]
# **Example:**

# %% [markdown]
# * this works for a lot of different relationships:
#
#     * `embedding(smallest) - embedding(small) + embedding(big) ≈ biggest`
#     * `embedding(Paris) - embedding(France) + embedding(Italy) ≈ Rome`
#
#
# * very complex relationships are accurately represented using this method
# * this scales very well

# %% [markdown]
# ## `Defining similarity`

# %% [markdown]
# * proving that two vectors are similar (e.g. Paris - France + Italy ≈ Rome) can be done using various methods:
# <br>
#
#     * using the Euclidean distance between two points
#         * Pythagora's theorem
#     * using the cosine similarity
#         * checks whether the two vectors are pointing in the same direction, the magnitude of the vectors is not important

# %% [markdown]
# <center><img src="https://edlitera-images.s3.amazonaws.com/euclidean_distance_and_cosine_similarity.png" width="700">
#
# source:
# <br>
# https://towardsdatascience.com/building-a-backend-system-for-artificial-intelligence-c404efade360

# %% [markdown]
# # `Keras Embedding Layer`

# %% [markdown]
# * Keras layer designed for embedding text data

# %% [markdown]
# **Can be used in multiple ways:**
#
# * Alone - to learn word embeddings which we can save for later and use in other models
#
#
# * Part of a Deep Learning model - embeddings are learned together with everything else
#
#
# * Transfer learning - loading pretrained embeddings

# %% [markdown]
# ## ` Layer arguments`

# %% [markdown]
# **Three important arguments we need to specify:**
#
# * input_dim
# * output_dim
# * input_length

# %% [markdown]
# ### `input_dim`

# %% [markdown]
# * vocabulary size

# %% [markdown]
# * directly connected with our integer encoded values
#     * if we have integer encoded values from 0-20, our vocabulary size would be 21
#     * this will also be the value we need to use for the **input_dim** argument

# %% [markdown]
# ### `output_dim`

# %% [markdown]
# * vector space size
#     * a vector space size of 100 will mean that each word gets encoded as a vector with 100 dimensions

# %% [markdown]
# * there is no "best value"
#     * usually we test out multiple values until we find the best one

# %% [markdown]
# ### `input_length`

# %% [markdown]
# * length of the input sequence

# %% [markdown]
# * works the same as for any other layer
#     * the total number of words in some document that gets processed in our embedding layer is our **input_length**

# %% [markdown]
# ## `Example`

# %%
# Import needed libraries

import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Load in data and create DataFrame

df = pd.read_csv("https://edlitera-datasets.s3.amazonaws.com/customer_complaints_dataset.csv")

# %%
# Take a look at our data

df
# Out:
#                                                   Product  \
# 0       Credit reporting, credit repair services, or o...
# 1       Credit reporting, credit repair services, or o...
# 2                             Checking or savings account
# 3                             Credit card or prepaid card
# 4       Credit reporting, credit repair services, or o...
# ...                                                   ...
# 752134                                        Credit card
# 752135                                    Debt collection
# 752136                                           Mortgage
# 752137                                   Credit reporting
# 752138                                   Credit reporting
#
#                              Consumer_complaint_narrative  category_id
# 0       I've reached out to Discover in the past. They...            0
# 1       Two accounts are still on my credit history af...            0
# 2       I have asked to close my Key Bank Checking acc...            1
# 3       I opened a citi double cash card the beginning...            2
# 4       There are several inaccuracies on my report th...            0
# ...                                                   ...          ...
# 752134  Automated calls from " XXXX with Capital One '...           10
# 752135  I have disputed my debts several times with no...            6
# 752136  My father died in XX/XX/XXXX. Left me his only...            4
# 752137  cfbp i would Like to file a complaint on Exper...            9
# 752138  My husband and I are in the middle of an FHA S...            9
#
# [752139 rows x 3 columns]

# %%
# Prepare dataframe sample

df = df.iloc[:125000, :]
df = df.sample(frac=1).reset_index(drop=True)

# %%
# Separate dependent feature from the independent feature

X = df["Consumer_complaint_narrative"]

y = df["category_id"]

# %%
# Take a look at our independent feature

X
# Out:
# 0         I am in desperate need of assistance postponin...
# 1         According to my recent credit report request f...
# 2         I was in the XXXX for a week my second year of...
# 3         This account is not mine, nor do I know whom i...
# 4         I have reachead out to Equifax about inaccurat...
#                                 ...
# 124995    After I have a total loss of my car the past X...
# 124996    ATTENTION DISPUTE DEPARTMENT XXXX, XXXX SOC SE...
# 124997    i sent in my normal payment on time and with e...
# 124998    XXXX loan through US Bank was not being report...
# 124999    On XX/XX/2020, my Bank of America debit card w...
# Name: Consumer_complaint_narrative, Length: 125000, dtype: object

# %%
# Take a look at our dependent feature

y
# Out:
# 0         4
# 1         0
# 2         6
# 3         6
# 4         0
#          ..
# 124995    5
# 124996    6
# 124997    4
# 124998    5
# 124999    2
# Name: category_id, Length: 125000, dtype: int64

# %%
# Separate data into training data and testing data

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
# Separate data into training data and validation data

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train, test_size=0.20, random_state=42
)

# %% [markdown]
# ### `Keras tokenizer`

# %% [markdown]
# * API for preparing text

# %%
#t  = Tokenizer()
t = Tokenizer(
    num_words=33, 
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\nx',
    oov_token="<OOV>")
fit_text = "The earth is an awesome place live"
t.fit_on_texts(fit_text)
sequences = t.texts_to_sequences(fit_text)

print("sequences : ",sequences,'\n')

print("word_index : ",t.word_index)
#[] specifies : 1. space b/w the words in the test_text    2. letters that have not occured in fit_text
# Out:
# sequences :  [[4], [5], [2], [], [2], [3], [9], [4], [5], [], [6], [7], [], [3], [10], [], [3], [11], [2], [7], [12], [13], [2], [], [14], [8], [3], [15], [2], [], [8], [6], [16], [2]]
#
# word_index :  {'<OOV>': 1, 'e': 2, 'a': 3, 't': 4, 'h': 5, 'i': 6, 's': 7, 'l': 8, 'r': 9, 'n': 10, 'w': 11, 'o': 12, 'm': 13, 'p': 14, 'c': 15, 'v': 16}

# %% [markdown]
# * a text tokenization class
#
# ```
# tf.keras.preprocessing.text.Tokenizer(
#     num_words=None,
#     filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#     lower=True, split=' ', oov_token=None,
#     document_count=0, **kwargs
# )
# ```

# %% [markdown]
# **Important arguments:**
#
#    * **num_words** - maximum number of words to keep, we define how many most frequent words we want to keep
#    * **filters** - input to the argument is a string; whatever is in that string will get removed
#    * **lower** - whether to convert text to lowercase
#    * **split** - defines how we split words
#    * **oov_token** - placeholder token for all out-of-vocabulary words used in text_to_sequence calls

# %%
from keras.preprocessing.text import Tokenizer

# %%
# Define tokenizer
# Set number of words as 10 000
# Set value of oov token
# Leave everything else on default values

tokenizer = Tokenizer(
    num_words=10_000, 
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\nx',
    oov_token="<OOV>")

# %% [markdown]
# **Keras tokenizer methods:**
#
#    * `fit_on_texts()`
#    * `texts_to_sequences()`
#    * `texts_to_matrix()`
#    * `sequences_to_matrix()`

# %% [markdown]
# * two important methods we will use are **`fit_on_texts()`** and **`texts_to_sequences()`**

# %% [markdown]
# **`fit_on_texts()`**
#
# * we use it to update our vocabulary of texts
# * the first thing that we use
# * **only use on training data**
#
# * attributes:
#     * word_counts - gives use all of the words inside the dictionary together with their counts
#     * word_docs - gives use all of the words inside the dictionary together with information on the number of documents that word appeared in
#     * word_index - unique integers, we assign one to each word
#     * document_count - total number of documents that we used to fit the tokenizer

# %%
# Fit tokenizer on train data

tokenizer.fit_on_texts(X_train)

# %% [markdown]
# **texts_to_sequences()**
#
# * converts tokens of some corpus into sequences of integers
# * used after fit_on_texts(), but before padding

# %%
# Convert into sequences of integers

X_train = tokenizer.texts_to_sequences(X_train)
X_valid = tokenizer.texts_to_sequences(X_valid)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
len(X_train)
# Out:
# 80000

# %%
X_train
# Out:
# [[75,
#   3667,
#   44,
#   2,
#   218,
#   365,
#   19,
#   6,
#   95,
#   653,
#   21,
#   34,
#   1639,
#   385,
#   28,
#   21,
#   7,
#   4105,
#   677,
#   24,
#   2,
#   3942,
#   8,
#   310,
#   19,
#   2952,
#   298,
#   77,
#   17,
#   38,
#   49,
#   1590,
#   61,
#   16,
#   137,
#   110,
#   56,
#   14,
#   133,
#   13,
#   24,
#   6,
#   116,
#   992,
#   2,
#   138,
#   2,
#   54,
#   5,
#   295,
#   13,
#   22,
#   21,
#   38,
#   450,
#   4,
#   20,
#   50,
#   17,
#   277,
#   706,
#   201,
#   5,
#   2099,
#   70,
#   631,
#   201],
#  [3,
#   48,
#   7,
#   91,
#   1327,
#   8,
#   5,
#   5,
#   11,
#   222,
#   4,
#   2485,
#   319,
#   1064,
#   10,
#   6,
#   125,
#   16,
#   211,
#   8,
#   176,
#   334,
#   202,
#   9,
#   63,
#   14,
#   1500,
#   85,
#   204,
#   12,
#   253,
#   90,
#   571,
#   8,
#   306,
#   97,
#   78,
#   5,
#   29,
#   665,
#   3,
#   48,
#   4106,
#   61,
#   334,
#   202,
#   1671,
#   10,
#   6,
#   28,
#   3,
#   235,
#   40,
#   131,
#   24,
#   6,
#   16,
#   211,
#   200,
#   3,
#   15,
#   219,
#   773,
#   2,
#   125,
#   137,
#   5,
#   117,
#   15,
#   14,
#   253,
#   2,
#   202,
#   25,
#   129,
#   220,
#   12,
#   105,
#   185,
#   81,
#   1278,
#   2,
#   16,
#   1351,
#   157,
#   3,
#   48,
#   14,
#   222,
#   4,
#   1402,
#   2105,
#   19,
#   6,
#   695,
#   5,
#   2521,
#   329,
#   639,
#   25,
#   7,
#   396,
#   8,
#   61,
#   334,
#   202,
#   1671,
#   12,
#   7,
#   16,
#   146,
#   19,
#   37,
#   188,
#   1569,
#   55,
#   150,
#   1451,
#   89,
#   159,
#   179,
#   167,
#   9164,
#   525,
#   571,
#   63,
#   14,
#   1500,
#   523,
#   55,
#   12,
#   1652,
#   384,
#   3456,
#   19,
#   707,
#   620,
#   117,
#   9164,
#   571,
#   63,
#   14,
#   1500,
#   55,
#   12,
#   1652,
#   384,
#   3456,
#   19,
#   707,
#   620,
#   125,
#   571,
#   63,
#   14,
#   1500,
#   90,
#   324,
#   251,
#   571,
#   63,
#   14,
#   1500,
#   90,
#   324,
#   273,
#   571,
#   63,
#   14,
#   1500,
#   90,
#   324,
#   426,
#   1676,
#   264,
#   1500,
#   1676,
#   523,
#   689,
#   502,
#   1676,
#   1706,
#   30,
#   264,
#   1500,
#   32,
#   5867,
#   1676,
#   564,
#   3327,
#   523,
#   689,
#   723,
#   177,
#   210,
#   14,
#   253,
#   611,
#   14,
#   253,
#   38,
#   78,
#   15,
#   36,
#   130,
#   10,
#   13,
#   22,
#   2087,
#   90,
#   1472,
#   32,
#   5496,
#   16,
#   565,
#   523,
#   1652,
#   384,
#   3456,
#   19,
#   55,
#   768,
#   5260,
#   8,
#   4539,
#   26,
#   19,
#   707,
#   620,
#   460,
#   285,
#   1178,
#   1178,
#   460,
#   285,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178,
#   1178],
#  [15,
#   138,
#   2,
#   16,
#   137,
#   10,
#   561,
#   956,
#   4,
#   15,
#   324,
#   29,
#   1965,
#   274,
#   30,
#   131,
#   217,
#   18,
#   31,
#   958,
#   4,
#   133,
#   2,
#   30,
#   248,
#   9,
#   202,
#   645,
#   84,
#   1142,
#   127,
#   458,
#   2,
#   30,
#   17,
#   250],
#  [75,
#   34,
#   161,
#   5,
#   679,
#   242,
#   596,
#   24,
#   32,
#   192,
#   445,
#   20,
#   8,
#   7,
#   516,
#   4,
#   6,
#   16,
#   193,
#   1178,
#   3,
#   748,
#   23,
#   10,
#   58,
#   793,
#   6,
#   193,
#   11,
#   1773,
#   2821,
#   599,
#   19,
#   1163,
#   38,
#   85,
#   46,
#   32,
#   192,
#   118,
#   32,
#   741,
#   260,
#   12,
#   6,
#   16,
#   381,
#   41,
#   636,
#   75,
#   98,
#   489,
#   24,
#   85,
#   272,
#   4,
#   204,
#   2842,
#   1,
#   3,
#   996,
#   7,
#   139,
#   77,
#   15,
#   36,
#   38,
#   1924,
#   1691,
#   29,
#   127,
#   2371,
#   8,
#   537,
#   8,
#   2,
#   139,
#   123,
#   2,
#   677,
#   103,
#   3,
#   715,
#   2,
#   32,
#   192,
#   793,
#   463,
#   5,
#   923,
#   6,
#   16,
#   193,
#   19,
#   35,
#   36,
#   1773,
#   1178,
#   599,
#   567,
#   8,
#   4691,
#   6,
#   68,
#   1428,
#   21,
#   32,
#   192,
#   121,
#   3,
#   72,
#   584,
#   5,
#   11,
#   290,
#   9,
#   6,
#   193,
#   35,
#   14,
#   36,
#   1773,
#   33,
#   40,
#   73,
#   9,
#   32,
#   192,
#   2489,
#   7,
#   336,
#   6211,
#   29,
#   5909,
#   4,
#   1341,
#   16,
#   963,
#   65,
#   77,
#   17,
#   85,
#   193,
#   253,
#   19,
#   10,
#   2,
#   32,
#   192,
#   1055,
#   5,
#   204,
#   85,
#   9,
#   17,
#   1003,
#   10,
#   2,
#   1055,
#   4,
#   20,
#   1281,
#   4326,
#   1099,
#   123,
#   32,
#   192,
#   35,
#   38,
#   32,
#   785,
#   19,
#   2,
#   1383,
#   12,
#   6,
#   193,
#   5,
#   75,
#   555,
#   20,
#   497,
#   12,
#   4233,
#   4,
#   88,
#   34,
#   32,
#   785,
#   686,
#   1801,
#   3,
#   1,
#   2,
#   244,
#   8,
#   7,
#   16,
#   4573,
#   136,
#   9,
#   118,
#   32,
#   741,
#   180,
#   2,
#   193,
#   18,
#   130,
#   11,
#   1623,
#   2821,
#   599,
#   65,
#   3,
#   160,
#   4,
#   100,
#   34,
#   1452,
#   136,
#   4,
#   32,
#   741,
#   180,
#   32,
#   192,
#   369,
#   13,
#   384,
#   9343,
#   4,
#   446,
#   2,
#   696,
#   63,
#   39,
#   1,
#   215,
#   1,
#   204,
#   191,
#   466,
#   4469,
#   17,
#   2,
#   331,
#   32,
#   192,
#   1,
#   20,
#   21,
#   16,
#   57,
#   1680,
#   5987,
#   4,
#   943,
#   6,
#   552,
#   16,
#   565,
#   13,
#   864,
#   183,
#   7,
#   4589,
#   8,
#   181,
#   4,
#   20,
#   228,
#   3912,
#   3,
#   15,
#   4,
#   1,
#   82,
#   658,
#   4,
#   1000,
#   21,
#   34,
#   191,
#   32,
#   192,
#   2614,
#   47,
#   80,
#   14,
#   29,
#   74,
#   14,
#   32,
#   741,
#   23,
#   1,
#   8,
#   7,
#   1174,
#   1,
#   33,
#   32,
#   192,
#   123,
#   18,
#   31,
#   5199,
#   25,
#   7,
#   6714,
#   12,
#   2,
#   2631,
#   3,
#   1270,
#   342,
#   13,
#   45,
#   27,
#   1463,
#   1291,
#   24,
#   236,
#   135,
#   16,
#   42,
#   136,
#   14,
#   7977,
#   854,
#   4,
#   2039,
#   2,
#   349,
#   8,
#   32,
#   192,
#   440,
#   39,
#   19,
#   82,
#   68],
#  [10,
#   411,
#   3,
#   175,
#   7,
#   826,
#   24,
#   6,
#   108,
#   55,
#   2457,
#   108,
#   46,
#   13,
#   68,
#   3,
#   35,
#   14,
#   255,
#   91,
#   2,
#   168,
#   8,
#   3,
#   503,
#   9,
#   2,
#   181,
#   93,
#   1048,
#   10,
#   2,
#   195,
#   73,
#   632,
#   2,
#   168,
#   8,
#   1687,
#   1847,
#   26,
#   3,
#   73,
#   503,
#   7,
#   3501,
#   26,
#   97,
#   302,
#   50,
#   357,
#   2457,
#   264,
#   14,
#   88,
#   2545,
#   238,
#   2,
#   8,
#   257,
#   168,
#   3,
#   72,
#   4,
#   477,
#   21,
#   7,
#   2457,
#   271,
#   5,
#   18,
#   59,
#   20,
#   4,
#   9,
#   3,
#   45,
#   15,
#   4,
#   100,
#   2,
#   5114,
#   1209,
#   29,
#   2,
#   826,
#   45,
#   14,
#   27,
#   1002,
#   24,
#   6,
#   164,
#   108,
#   55,
#   18,
#   73,
#   187,
#   9,
#   37,
#   2,
#   424,
#   2953,
#   45,
#   27,
#   1069,
#   4,
#   20,
#   350,
#   2,
#   51,
#   11,
#   91,
#   119,
#   3,
#   91,
#   2,
#   168,
#   8,
#   65,
#   25,
#   4,
#   27,
#   99,
#   4,
#   103,
#   5,
#   175,
#   34,
#   482,
#   100,
#   119,
#   10,
#   411,
#   3,
#   53,
#   7,
#   4025,
#   826,
#   195,
#   50,
#   38,
#   529,
#   2091,
#   7,
#   97,
#   302,
#   47,
#   23,
#   17,
#   110,
#   1147,
#   4008,
#   26,
#   19,
#   2,
#   168,
#   8,
#   77,
#   31,
#   38,
#   1700,
#   266,
#   29,
#   135,
#   266,
#   1048,
#   10,
#   2,
#   207,
#   826,
#   195,
#   2,
#   108,
#   11,
#   2005,
#   12,
#   198,
#   10,
#   411,
#   3,
#   35,
#   7,
#   989,
#   447,
#   90,
#   4,
#   27,
#   507,
#   4,
#   20,
#   12,
#   2,
#   93,
#   8,
#   1306,
#   26,
#   25,
#   190,
#   25,
#   2,
#   4008,
#   26,
#   1222,
#   181,
#   43,
#   19,
#   2,
#   108,
#   583,
#   12,
#   11,
#   38,
#   529,
#   845,
#   33,
#   2457,
#   5,
#   11,
#   91,
#   12,
#   198,
#   10,
#   411,
#   75,
#   176,
#   692,
#   8,
#   871,
#   4,
#   774,
#   2457,
#   5,
#   389,
#   38,
#   189,
#   3,
#   56,
#   221,
#   2,
#   447,
#   146,
#   19,
#   1361,
#   26,
#   18,
#   939,
#   91,
#   4277,
#   26,
#   21,
#   38,
#   32,
#   785,
#   5,
#   4,
#   103,
#   18,
#   15,
#   14,
#   507,
#   2,
#   2953,
#   12,
#   2,
#   181,
#   19,
#   3,
#   15,
#   224,
#   724,
#   8,
#   265,
#   100,
#   119,
#   866,
#   7,
#   209,
#   8,
#   7,
#   195,
#   1878,
#   2,
#   447,
#   90,
#   25,
#   4993,
#   26,
#   75,
#   6,
#   43,
#   25,
#   190,
#   25,
#   719,
#   8,
#   2,
#   51,
#   826,
#   4,
#   2457,
#   10,
#   411,
#   5,
#   2,
#   146,
#   209,
#   19,
#   2,
#   447,
#   258,
#   89,
#   159,
#   20,
#   88,
#   13,
#   521,
#   5,
#   2,
#   1015,
#   90,
#   8,
#   6,
#   2953,
#   507,
#   4,
#   20,
#   440,
#   39],
#  [1199,
#   2375,
#   2822,
#   1197,
#   3,
#   160,
#   4,
#   116,
#   7,
#   139,
#   19,
#   7,
#   4703,
#   4553,
#   288,
#   277,
#   1,
#   108,
#   55,
#   12,
#   2126,
#   3,
#   11,
#   2275,
#   33,
#   2,
#   55,
#   24,
#   238,
#   3,
#   15,
#   36,
#   7,
#   51,
#   3125,
#   12,
#   2,
#   108,
#   2631,
#   19,
#   105,
#   1059,
#   154,
#   329,
#   2,
#   798,
#   168,
#   8,
#   6,
#   1,
#   21,
#   1,
#   2,
#   55,
#   547,
#   362,
#   20,
#   593,
#   464,
#   58,
#   1,
#   10,
#   2,
#   51,
#   1359,
#   225,
#   2,
#   51,
#   93,
#   18,
#   1157,
#   3741,
#   20,
#   19,
#   2,
#   6645,
#   1806,
#   32,
#   5017,
#   9,
#   62,
#   1087,
#   83,
#   4,
#   58,
#   3030,
#   1667,
#   4,
#   263,
#   29,
#   448,
#   278,
#   12,
#   7,
#   814,
#   1,
#   8,
#   61,
#   51,
#   1451,
#   62,
#   674,
#   5647,
#   8,
#   1397,
#   81,
#   4,
#   448,
#   83,
#   4,
#   2,
#   1062,
#   8,
#   51,
#   1020,
#   5,
#   511,
#   1,
#   949,
#   18,
#   5497,
#   294,
#   20,
#   174,
#   225,
#   6,
#   860,
#   1118,
#   19,
#   301,
#   278,
#   9,
#   62,
#   2111,
#   230,
#   1266,
#   166,
#   3,
#   48,
#   1879,
#   34,
#   161,
#   24,
#   2,
#   1779,
#   8,
#   2,
#   55,
#   50,
#   32,
#   3600,
#   7536,
#   61,
#   707,
#   1761,
#   3,
#   48,
#   73,
#   1879,
#   7,
#   209,
#   8,
#   6,
#   318,
#   359,
#   21,
#   6,
#   578,
#   1190,
#   50,
#   32,
#   3600,
#   7536,
#   6,
#   51,
#   78,
#   9,
#   62,
#   710,
#   12,
#   494,
#   21,
#   2,
#   4703,
#   4553,
#   9,
#   390,
#   9,
#   8973,
#   80,
#   38,
#   529,
#   27,
#   4870,
#   593,
#   464,
#   2,
#   1,
#   8,
#   2,
#   51,
#   111,
#   593,
#   464,
#   2,
#   51,
#   93,
#   3,
#   48,
#   1914,
#   8,
#   1032,
#   13,
#   937,
#   33,
#   1,
#   17,
#   627,
#   2698,
#   4,
#   6,
#   278,
#   25,
#   34,
#   3125,
#   29,
#   64,
#   23,
#   17,
#   7,
#   55,
#   5393,
#   1386,
#   19,
#   2,
#   135,
#   426,
#   51,
#   8973,
#   46,
#   2,
#   55,
#   217,
#   3,
#   45,
#   183,
#   4,
#   120,
#   34,
#   220,
#   8,
#   13,
#   245,
#   33,
#   39,
#   46,
#   82,
#   3346,
#   440,
#   39,
#   19,
#   82,
#   68,
#   3172],
#  [13,
#   17,
#   14,
#   1782,
#   3,
#   48,
#   12,
#   537,
#   8,
#   7,
#   1149,
#   1928,
#   76,
#   24,
#   82,
#   55,
#   5821,
#   884,
#   6932,
#   493,
#   3722,
#   236,
#   1072,
#   8,
#   49,
#   23,
#   17,
#   6,
#   711,
#   4,
#   100,
#   44,
#   1418,
#   769,
#   47,
#   73,
#   14,
#   27,
#   4043,
#   33,
#   1,
#   7739,
#   82,
#   399,
#   31,
#   7537,
#   1002,
#   196,
#   39,
#   1548,
#   20,
#   21,
#   7,
#   163,
#   295,
#   129,
#   1707,
#   8,
#   2258,
#   132,
#   31,
#   39,
#   63,
#   3,
#   15,
#   7,
#   262,
#   21,
#   39,
#   89,
#   199,
#   20,
#   7,
#   430,
#   209,
#   8,
#   2,
#   262,
#   9,
#   32,
#   1692,
#   684,
#   5,
#   22,
#   650,
#   1693,
#   49,
#   89,
#   299,
#   82,
#   163,
#   129,
#   1,
#   5,
#   1908,
#   9,
#   13,
#   17,
#   7,
#   649,
#   49,
#   5,
#   14,
#   7,
#   92,
#   3254,
#   357,
#   2,
#   680,
#   1056,
#   314,
#   1185,
#   7,
#   46,
#   312,
#   425,
#   208,
#   314,
#   1686,
#   32,
#   1971,
#   64,
#   39,
#   1113,
#   13,
#   25,
#   7,
#   49,
#   92,
#   2607,
#   4,
#   142,
#   104,
#   25,
#   7,
#   49,
#   628,
#   440,
#   39,
#   19,
#   362,
#   119,
#   2,
#   241,
#   232,
#   4,
#   485,
#   17,
#   232,
#   4,
#   1940,
#   232,
#   4,
#   737,
#   17,
#   232,
#   4,
#   485,
#   2673,
#   17,
#   4309],
#  [13,
#   55,
#   17,
#   467,
#   6,
#   1262,
#   105,
#   5,
#   105,
#   230,
#   18,
#   15,
#   72,
#   6,
#   1262,
#   426,
#   147,
#   18,
#   15,
#   72,
#   20,
#   24,
#   2,
#   112,
#   581,
#   253,
#   18,
#   74,
#   96,
#   5,
#   2236,
#   99,
#   29,
#   18,
#   74,
#   96,
#   5,
#   423,
#   19,
#   20,
#   379,
#   1097,
#   4,
#   6,
#   890,
#   3896,
#   1665,
#   183,
#   7,
#   2565,
#   3,
#   318,
#   19,
#   7,
#   55,
#   5,
#   18,
#   31,
#   467,
#   1665,
#   183,
#   5140,
#   5,
#   18,
#   31,
#   7,
#   49,
#   628,
#   6,
#   1262,
#   41,
#   175,
#   19,
#   40,
#   4,
#   518,
#   467],
#  [120,
#   19,
#   720,
#   1022,
#   16,
#   28,
#   3,
#   342,
#   9,
#   257,
#   70,
#   42,
#   136,
#   41,
#   2317,
#   2,
#   649,
#   4060,
#   8,
#   2,
#   212,
#   5,
#   344,
#   16,
#   456,
#   157,
#   2,
#   157,
#   186,
#   1769,
#   3825,
#   11,
#   1788,
#   4,
#   2318,
#   7,
#   606,
#   2938,
#   1798,
#   697,
#   1269,
#   118,
#   557,
#   7,
#   209,
#   8,
#   58,
#   16,
#   211,
#   46,
#   696,
#   350,
#   7,
#   275,
#   720,
#   8,
#   170,
#   123,
#   257,
#   16,
#   42,
#   136,
#   107,
#   41,
#   1929,
#   4432,
#   215,
#   25,
#   5,
#   2,
#   4397,
#   368,
#   4,
#   557,
#   2,
#   720,
#   1022,
#   211,
#   17,
#   4554,
#   165,
#   34,
#   30,
#   120,
#   4,
#   4327,
#   1269,
#   165,
#   424,
#   1253,
#   1680,
#   9,
#   31,
#   32,
#   2042,
#   5,
#   2386,
#   127,
#   458,
#   3,
#   234,
#   15,
#   53,
#   34,
#   1043,
#   8,
#   34,
#   482,
#   16,
#   28,
#   24,
#   479,
#   32,
#   192,
#   29,
#   2983,
#   23,
#   17,
#   809,
#   9,
#   3,
#   160,
#   4,
#   63,
#   7,
#   206,
#   120,
#   123,
#   3,
#   80,
#   772,
#   6,
#   274,
#   30,
#   141,
#   2,
#   70,
#   233,
#   631,
#   297,
#   386,
#   1492,
#   3,
#   342,
#   9,
#   123,
#   2,
#   386,
#   17,
#   2,
#   1649,
#   654,
#   2133,
#   585,
#   8,
#   2,
#   212,
#   16,
#   42,
#   157,
#   228,
#   3838,
#   9,
#   37,
#   424,
#   3654,
#   8,
#   30,
#   24,
#   2,
#   16,
#   137,
#   122,
#   27,
#   589,
#   1480,
#   3,
#   653,
#   21,
#   37,
#   135,
#   2164,
#   122,
#   221,
#   7,
#   720,
#   16,
#   28,
#   464,
#   120,
#   2,
#   16,
#   42,
#   280,
#   31,
#   34,
#   1461,
#   3767,
#   8,
#   2,
#   916,
#   794,
#   368,
#   4,
#   817,
#   3186,
#   47,
#   2,
#   333,
#   2632,
#   1929,
#   4026,
#   3972,
#   1269,
#   19,
#   34,
#   3395,
#   1509,
#   193,
#   41,
#   945,
#   635,
#   981,
#   469,
#   47,
#   14,
#   1053,
#   4,
#   32,
#   192,
#   60,
#   254,
#   528,
#   4,
#   7,
#   1798,
#   3709,
#   9,
#   17,
#   212,
#   19,
#   44,
#   612,
#   12,
#   2,
#   917,
#   390,
#   5,
#   60,
#   254,
#   27,
#   222,
#   4,
#   120,
#   424,
#   1929,
#   10,
#   126,
#   487,
#   611,
#   1629,
#   3,
#   48,
#   410,
#   7,
#   120,
#   19,
#   7,
#   720,
#   16,
#   28,
#   21,
#   719,
#   86,
#   4,
#   6,
#   224,
#   161,
#   149,
#   440,
#   39],
#  [3, 15, 38, 438, 8, 2, 227, 213, 587, 89, 519, 4, 821, 77, 17, 38, 140, 620],
#  [5,
#   31,
#   2,
#   614,
#   455,
#   5,
#   3002,
#   614,
#   455,
#   8,
#   2,
#   1642,
#   281,
#   16,
#   779,
#   10,
#   18,
#   31,
#   5,
#   18,
#   15,
#   4043,
#   6,
#   22,
#   8,
#   6259,
#   8,
#   1852,
#   8,
#   648,
#   12,
#   32,
#   2042,
#   2546,
#   123,
#   2,
#   52,
#   4574,
#   18,
#   15,
#   1,
#   20,
#   24,
#   98,
#   222,
#   4,
#   178,
#   2,
#   2528,
#   12,
#   37,
#   315,
#   5087,
#   29,
#   514,
#   135,
#   225,
#   33,
#   161,
#   3,
#   48,
#   337,
#   9,
#   2,
#   3754,
#   519,
#   40,
#   19,
#   104,
#   5460,
#   8506,
#   7158,
#   1,
#   5,
#   4290,
#   40,
#   5,
#   1585,
#   40,
#   24,
#   2528,
#   1033,
#   1480,
#   25,
#   18,
#   31,
#   265],
#  [3,
#   15,
#   7,
#   92,
#   10,
#   6,
#   16,
#   28,
#   19,
#   7,
#   1287,
#   26,
#   152,
#   587,
#   2,
#   177,
#   210,
#   17,
#   2,
#   92,
#   136,
#   17,
#   3,
#   608,
#   4,
#   7,
#   743,
#   359,
#   21,
#   4,
#   100,
#   2682,
#   26,
#   8,
#   2,
#   1287,
#   26,
#   92,
#   4,
#   448,
#   5,
#   133,
#   2,
#   22,
#   50,
#   3,
#   91,
#   2,
#   92,
#   17,
#   110,
#   98,
#   130,
#   339,
#   600,
#   12,
#   2,
#   263,
#   8,
#   1719,
#   6,
#   186,
#   188,
#   5,
#   13,
#   92,
#   110,
#   98,
#   130,
#   41,
#   6,
#   539,
#   46,
#   7,
#   2186,
#   110,
#   3,
#   80,
#   14,
#   1770,
#   37,
#   421,
#   1719,
#   7,
#   188,
#   71,
#   8,
#   13,
#   130,
#   92,
#   376,
#   91,
#   2,
#   49,
#   25,
#   495,
#   5,
#   48,
#   110,
#   98,
#   6450,
#   25,
#   64,
#   3,
#   377,
#   100,
#   2,
#   49,
#   3,
#   219,
#   13,
#   21,
#   2,
#   16,
#   137,
#   5,
#   128,
#   40,
#   4,
#   519,
#   5,
#   175,
#   44,
#   268,
#   1311,
#   283,
#   18,
#   608,
#   99,
#   21,
#   2,
#   1287,
#   26,
#   90,
#   602,
#   12,
#   94,
#   436,
#   81,
#   5,
#   3,
#   67,
#   53,
#   37,
#   268,
#   50,
#   786,
#   18,
#   377,
#   519,
#   284,
#   3,
#   102,
#   138,
#   372,
#   19,
#   454,
#   1405,
#   4,
#   133,
#   2,
#   91,
#   92,
#   5,
#   3553,
#   94,
#   180,
#   18,
#   15,
#   14,
#   131,
#   2,
#   1044,
#   22,
#   24,
#   6,
#   28,
#   3,
#   11,
#   59,
#   9,
#   2,
#   262,
#   18,
#   15,
#   21,
#   58,
#   1121,
#   1012,
#   235,
#   284,
#   131,
#   24,
#   2,
#   28,
#   38,
#   245,
#   109,
#   2,
#   349,
#   8,
#   2,
#   92,
#   17,
#   113,
#   3,
#   102,
#   138,
#   5988,
#   490,
#   272,
#   5,
#   32,
#   474,
#   6,
#   439,
#   4,
#   40,
#   5,
#   128,
#   180,
#   58,
#   262,
#   21,
#   1012,
#   682,
#   19,
#   91,
#   392,
#   4,
#   27,
#   131,
#   2,
#   5988,
#   490,
#   272,
#   290,
#   20,
#   9,
#   77,
#   17,
#   38,
#   262,
#   329,
#   6,
#   112,
#   96,
#   21,
#   5988,
#   490,
#   3,
#   308,
#   79,
#   9,
#   9,
#   56,
#   14,
#   441,
#   570,
#   365,
#   350,
#   3,
#   91,
#   2,
#   743,
#   18,
#   62,
#   712,
#   4,
#   178,
#   4,
#   985,
#   40,
#   60,
#   608,
#   4,
#   7,
#   743,
#   359,
#   9,
#   3,
#   91,
#   5,
#   2,
#   1015,
#   90,
#   8,
#   2003,
#   26,
#   8,
#   2,
#   177,
#   49,
#   11,
#   4,
#   27,
#   861,
#   4,
#   20,
#   25,
#   7,
#   90,
#   8,
#   371,
#   26,
#   50,
#   67,
#   562,
#   778,
#   9,
#   3,
#   110,
#   35,
#   34,
#   982,
#   90,
#   8,
#   2003,
#   26,
#   64,
#   2,
#   2,
#   16,
#   137,
#   35,
#   817,
#   799,
#   5,
#   5648,
#   2,
#   268,
#   3,
#   175,
#   13,
#   122,
#   15,
#   36,
#   1298,
#   4,
#   2927,
#   3,
#   11,
#   59,
#   4,
#   178,
#   5,
#   116,
#   7,
#   139,
#   21,
#   2,
#   612,
#   233,
#   631,
#   297,
#   310,
#   444,
#   2984,
#   401,
#   5,
#   7,
#   70,
#   201,
#   201,
#   1190,
#   440,
#   39,
#   19,
#   82,
#   68],
#  [3,
#   15,
#   36,
#   1171,
#   508,
#   19,
#   176,
#   166,
#   107,
#   277,
#   2,
#   52,
#   9,
#   61,
#   301,
#   137,
#   366,
#   2071,
#   12,
#   6,
#   16,
#   28,
#   3,
#   15,
#   345,
#   4,
#   342,
#   9,
#   61,
#   52,
#   31,
#   44,
#   184,
#   5,
#   884,
#   30,
#   47,
#   18,
#   366,
#   298,
#   99,
#   12,
#   6,
#   28,
#   18,
#   15,
#   14,
#   1209,
#   37,
#   286,
#   450,
#   4,
#   655,
#   9,
#   61,
#   52,
#   62,
#   87,
#   33,
#   20,
#   29,
#   1599,
#   33,
#   20,
#   12,
#   404,
#   166,
#   9,
#   3,
#   15,
#   36,
#   372,
#   19,
#   144,
#   29,
#   37,
#   346,
#   359,
#   3,
#   128,
#   19,
#   286,
#   2536,
#   5,
#   11,
#   290,
#   9,
#   109,
#   18,
#   31,
#   481,
#   17,
#   277,
#   6,
#   418,
#   5,
#   17,
#   14,
#   752,
#   21,
#   2,
#   229,
#   706,
#   13,
#   41,
#   36,
#   885,
#   20,
#   3430,
#   1092,
#   5,
#   3421,
#   34,
#   4555,
#   14,
#   4,
#   1437,
#   233,
#   1324,
#   1099,
#   12,
#   61,
#   147,
#   8,
#   807,
#   18,
#   15,
#   14,
#   36,
#   243,
#   1936,
#   12,
#   1831,
#   61,
#   2259,
#   5,
#   3,
#   15,
#   36,
#   1,
#   10,
#   674,
#   40,
#   4,
#   328,
#   4,
#   367,
#   13,
#   217,
#   23,
#   45,
#   27,
#   174,
#   1936,
#   19,
#   20,
#   4,
#   15,
#   2,
#   52,
#   760,
#   3890,
#   1359,
#   225,
#   296,
#   5,
#   1200,
#   2,
#   1656,
#   345,
#   19,
#   20,
#   855,
#   40,
#   2214,
#   85,
#   174,
#   1755,
#   4,
#   63,
#   2,
#   300,
#   685,
#   5,
#   133,
#   44,
#   61,
#   184,
#   5,
#   1304,
#   30,
#   24,
#   6,
#   16,
#   28,
#   3,
#   1144,
#   39,
#   118,
#   159,
#   20,
#   4,
#   6933,
#   2927,
#   4,
#   40,
#   261,
#   2,
#   245,
#   440,
#   39,
#   5,
#   1144,
#   4,
#   1108,
#   24,
#   39,
#   572],
#  [623,
#   54,
#   95,
#   849,
#   89,
#   490,
#   2,
#   224,
#   116,
#   454,
#   1138,
#   10,
#   151,
#   3,
#   87,
#   7,
#   397,
#   10,
#   3,
#   246,
#   6,
#   623,
#   54,
#   2783,
#   16,
#   57,
#   4,
#   142,
#   2,
#   397,
#   2,
#   356,
#   11,
#   2720,
#   33,
#   7,
#   576,
#   585,
#   727,
#   431,
#   2,
#   244,
#   8,
#   2,
#   356,
#   11,
#   2720,
#   12,
#   6,
#   1,
#   150,
#   124,
#   71,
#   114,
#   45,
#   27,
#   188,
#   64,
#   2,
#   1258,
#   62,
#   1326,
#   12,
#   1683,
#   197,
#   531,
#   23,
#   65,
#   562,
#   9,
#   3,
#   11,
#   188,
#   24,
#   318,
#   10,
#   151,
#   66,
#   2,
#   1258,
#   11,
#   1326,
#   6,
#   2396,
#   346,
#   19,
#   2,
#   1258,
#   12,
#   6,
#   2405,
#   5,
#   2,
#   1743,
#   3267,
#   554,
#   60,
#   152,
#   2,
#   1258,
#   729,
#   200,
#   5,
#   308,
#   2,
#   4892,
#   4816,
#   3,
#   6100,
#   79,
#   4,
#   148,
#   2,
#   3267,
#   47,
#   114,
#   11,
#   320,
#   945,
#   3,
#   72,
#   10,
#   2,
#   169,
#   162,
#   151,
#   5,
#   2,
#   485,
#   962,
#   9,
#   18,
#   45,
#   3554,
#   367,
#   23,
#   33,
#   1,
#   34,
#   3555,
#   220,
#   18,
#   865,
#   2,
#   727,
#   5,
#   2,
#   727,
#   602,
#   12,
#   7,
#   483,
#   81,
#   2,
#   822,
#   11,
#   8,
#   38,
#   658,
#   2144,
#   5,
#   59,
#   20,
#   9,
#   2,
#   1258,
#   122,
#   14,
#   15,
#   36,
#   346,
#   19,
#   64,
#   23,
#   62,
#   4816,
#   1219,
#   39,
#   77,
#   11,
#   38,
#   315,
#   4,
#   15,
#   1403,
#   8,
#   2,
#   4892,
#   8,
#   2,
#   1258,
#   1050,
#   23,
#   11,
#   152,
#   1410,
#   9,
#   11,
#   23,
#   21,
#   40,
#   3,
#   72,
#   121,
#   5,
#   18,
#   962,
#   20,
#   9,
#   18,
#   45,
#   226,
#   568,
#   8,
#   23,
#   5,
#   3,
#   45,
#   148,
#   2,
#   16,
#   1133,
#   10,
#   6,
#   16,
#   57,
#   230,
#   7,
#   483,
#   81,
#   66,
#   23,
#   56,
#   14,
#   994,
#   3,
#   72,
#   40,
#   84,
#   5,
#   102,
#   296,
#   9,
#   162,
#   3,
#   53,
#   34,
#   161,
#   24,
#   40,
#   9,
#   18,
#   45,
#   14,
#   63,
#   284,
#   94,
#   23,
#   5,
#   23,
#   17,
#   156,
#   6,
#   135,
#   812,
#   11,
#   4,
#   774,
#   79,
#   4,
#   623,
#   54,
#   25,
#   18,
#   644,
#   2,
#   16,
#   57,
#   10,
#   151,
#   3,
#   573,
#   79,
#   4,
#   623,
#   54,
#   5,
#   1240,
#   44,
#   8,
#   109,
#   3,
#   101,
#   12,
#   2,
#   7445,
#   1414,
#   173,
#   570,
#   18,
#   59,
#   20,
#   9,
#   18,
#   428,
#   2,
#   727,
#   238,
#   151,
#   4,
#   533,
#   10,
#   151,
#   3,
#   53,
#   34,
#   161,
#   24,
#   623,
#   54,
#   372,
#   20,
#   4,
#   787,
#   7,
#   434,
#   5,
#   199,
#   23,
#   84,
#   4,
#   40,
#   23,
#   562,
#   9,
#   3,
#   11,
#   46,
#   2,
#   4817,
#   3925,
#   3220,
#   25,
#   3,
#   48,
#   5,
#   3,
#   118,
#   14,
#   533,
#   4,
#   40,
#   230,
#   2,
#   187,
#   68,
#   66,
#   3,
#   249,
#   4,
#   623,
#   54,
#   3,
#   59,
#   40,
#   2,
#   30,
#   18,
#   31,
#   337,
#   11,
#   30,
#   3,
#   320,
#   196,
#   105,
#   2,
#   112,
#   21,
#   2,
#   271,
#   132,
#   1846,
#   2,
#   139,
#   10,
#   151,
#   3,
#   249,
#   21,
#   7,
#   545,
#   46,
#   623,
#   54,
#   132,
#   128,
#   20,
#   4,
#   1338,
#   7,
#   76,
#   5,
#   32,
#   741,
#   109,
#   562,
#   3,
#   59,
#   216,
#   3,
#   56,
#   9,
#   2,
#   243,
#   186,
#   68,
#   5,
#   106,
#   59,
#   20,
#   9,
#   2,
#   271,
#   132,
#   1300,
#   369,
#   6934,
#   2,
#   95,
#   56,
#   14,
#   317,
#   44,
#   8,
#   109,
#   3,
#   59,
#   393,
#   12,
#   2,
#   368,
#   3,
#   2276,
#   5,
#   69,
#   2,
#   30,
#   161,
#   684,
#   575,
#   5,
#   2,
#   576,
#   585,
#   727,
#   2,
#   442,
#   242,
#   162,
#   151,
#   303,
#   609,
#   3,
#   15,
#   224,
#   2,
#   434,
#   50,
#   3,
#   609,
#   443,
#   105,
#   4,
#   40,
#   10,
#   151,
#   3,
#   53,
#   34,
#   161,
#   24,
#   40,
#   623,
#   54,
#   50,
#   59,
#   20,
#   9,
#   3,
#   56,
#   14,
#   533,
#   4,
#   40,
#   12,
#   2,
#   340,
#   68,
#   151,
#   3,
#   573,
#   79,
#   4,
#   40,
#   121,
#   303,
#   1562,
#   3,
#   59,
#   40,
#   3,
#   196,
#   260,
#   164,
#   71,
#   44,
#   8,
#   9,
#   30,
#   11,
#   320,
#   12,
#   2,
#   95,
#   4,
#   3564,
#   6,
#   163,
#   24,
#   2,
#   88,
#   347,
#   18,
#   59,
#   20,
#   9,
#   3,
#   118,
#   6212,
#   2,
#   163,
#   33,
#   467,
#   66,
#   3,
#   72,
#   40,
#   10,
#   151,
#   18,
#   59,
#   20,
#   9,
#   2,
#   68,
#   41,
#   1065,
#   71,
#   3,
#   56,
#   14,
#   533,
#   12,
#   68,
#   3,
#   128,
#   40,
#   155,
#   355,
#   81,
#   63,
#   3,
#   88,
#   4,
#   533,
#   2293,
#   5,
#   2,
#   485,
#   101,
#   1082,
#   81,
#   113,
#   3,
#   59,
#   216,
#   17,
#   14,
#   1082,
#   81,
#   106,
#   547,
#   4,
#   88,
#   1815,
#   5,
#   56,
#   14,
#   172,
#   109,
#   4,
#   446,
#   106,
#   962,
#   4,
#   199,
#   7,
#   120,
#   4,
#   1618,
#   2,
#   95,
#   5,
#   3,
#   122,
#   1108,
#   24,
#   40,
#   12,
#   436,
#   197,
#   81,
#   44,
#   18,
#   31,
#   481,
#   17,
#   3556,
#   20,
#   497,
#   4,
#   1,
#   14,
#   832,
#   8,
#   40,
#   17,
#   1126,
#   4,
#   1646,
#   2,
#   439,
#   3,
#   48,
#   372,
#   39,
#   4,
#   944,
#   440,
#   39,
#   243,
#   500],
#  [3,
#   152,
#   7,
#   1881,
#   22,
#   21,
#   6,
#   1216,
#   71,
#   114,
#   11,
#   7,
#   3576,
#   5,
#   247,
#   422,
#   186,
#   647,
#   21,
#   5,
#   365,
#   4,
#   564,
#   5,
#   538,
#   805,
#   570,
#   11,
#   270,
#   190,
#   238,
#   114,
#   11,
#   138,
#   303,
#   33,
#   279,
#   248,
#   9,
#   18,
#   45,
#   100,
#   393,
#   4,
#   941,
#   5941,
#   4,
#   5868,
#   58,
#   5,
#   114,
#   365,
#   4,
#   321,
#   40,
#   422,
#   22,
#   30,
#   65,
#   9,
#   422,
#   805,
#   118,
#   27,
#   863,
#   165,
#   422,
#   22,
#   428,
#   40,
#   422,
#   22,
#   30,
#   66,
#   23,
#   11,
#   68,
#   19,
#   393,
#   4,
#   88,
#   91,
#   10,
#   151,
#   114,
#   503,
#   104,
#   11,
#   98,
#   863,
#   165,
#   422,
#   22,
#   47,
#   2,
#   104,
#   11,
#   98,
#   131,
#   38,
#   3890,
#   9,
#   23,
#   11,
#   863,
#   72,
#   20,
#   24,
#   927,
#   4,
#   351,
#   20,
#   109,
#   11,
#   270,
#   10,
#   47,
#   33,
#   102,
#   23,
#   11,
#   635,
#   97,
#   3,
#   237,
#   716,
#   21,
#   38,
#   6798,
#   13,
#   11,
#   7,
#   1881,
#   22,
#   5,
#   6,
#   1216,
#   11,
#   7,
#   3576,
#   383,
#   1021,
#   8,
#   5,
#   2171,
#   5,
#   107,
#   60,
#   31,
#   10,
#   2,
#   6935,
#   19,
#   104,
#   60,
#   31,
#   14,
#   654,
#   19,
#   3,
#   45,
#   183,
#   19,
#   6,
#   22,
#   4,
#   27,
#   3630,
#   71,
#   3,
#   15,
#   7,
#   1,
#   55,
#   5,
#   3,
#   48,
#   7,
#   3396,
#   816,
#   3,
#   732,
#   160,
#   6,
#   54,
#   22],
#  [4002,
#   3768,
#   1169,
#   73,
#   481,
#   197,
#   25,
#   10,
#   6,
#   16,
#   28,
#   3555,
#   12,
#   713,
#   4,
#   22,
#   86,
#   13,
#   11,
#   34,
#   470,
#   51,
#   3,
#   11,
#   510,
#   2537,
#   10,
#   19,
#   6,
#   32,
#   2515,
#   60,
#   3866,
#   12,
#   5,
#   12,
#   2,
#   3958,
#   6,
#   32,
#   2515,
#   771,
#   9,
#   304,
#   5,
#   44,
#   891,
#   49,
#   102,
#   296,
#   9,
#   275,
#   6,
#   32,
#   659,
#   9,
#   492,
#   4,
#   27,
#   2204,
#   5,
#   102,
#   6715,
#   79,
#   10,
#   2,
#   49,
#   12,
#   7,
#   201,
#   1190,
#   12,
#   3555,
#   138,
#   20,
#   10,
#   797,
#   8,
#   13,
#   210,
#   5,
#   646,
#   2,
#   2081,
#   3958,
#   2117,
#   9,
#   3,
#   254,
#   100,
#   2,
#   49,
#   1828,
#   29,
#   15,
#   6,
#   2260,
#   2833,
#   3,
#   15,
#   454,
#   16,
#   7238,
#   65,
#   12,
#   382,
#   4,
#   1217,
#   6,
#   16,
#   3,
#   3680,
#   7,
#   743,
#   21,
#   40,
#   8,
#   1424,
#   26,
#   4,
#   821,
#   2,
#   22,
#   67,
#   256,
#   10,
#   6,
#   16,
#   25,
#   7,
#   1784,
#   29,
#   1488,
#   49,
#   13,
#   22,
#   11,
#   1044,
#   12,
#   198,
#   19,
#   702,
#   225,
#   2,
#   90,
#   354,
#   113,
#   10,
#   3,
#   705,
#   7,
#   76,
#   24,
#   2,
#   286,
#   1190,
#   3555,
#   248,
#   13,
#   331,
#   3,
#   773,
#   23,
#   11,
#   305,
#   5,
#   954,
#   20,
#   3,
#   15,
#   224,
#   9,
#   76,
#   4,
#   13,
#   139,
#   1197,
#   13,
#   51,
#   55,
#   41,
#   1,
#   579,
#   4,
#   317,
#   13,
#   84,
#   10,
#   6,
#   16,
#   28,
#   416,
#   123,
#   2261,
#   2071,
#   25,
#   7,
#   170,
#   119,
#   135,
#   147,
#   2071,
#   25,
#   110,
#   354,
#   49,
#   8,
#   5,
#   667,
#   463,
#   12,
#   18,
#   788,
#   23,
#   10,
#   25,
#   7,
#   392,
#   22,
#   21,
#   354,
#   10,
#   23,
#   3,
#   15,
#   827,
#   219,
#   13,
#   5,
#   35,
#   23,
#   131,
#   319,
#   147,
#   257,
#   68,
#   23,
#   17,
#   945,
#   19,
#   7,
#   379,
#   5,
#   102,
#   23,
#   1549,
#   84,
#   121,
#   3,
#   15,
#   224,
#   34,
#   3783,
#   8,
#   155,
#   6,
#   28,
#   993,
#   12,
#   21,
#   83,
#   5,
#   25,
#   7,
#   91,
#   2964,
#   50,
#   17,
#   155,
#   23,
#   993,
#   75,
#   3,
#   207,
#   219,
#   23,
#   5,
#   204,
#   3783,
#   8,
#   155,
#   6,
#   28,
#   2130,
#   107,
#   12,
#   283,
#   18,
#   15,
#   107,
#   1302,
#   5,
#   788,
#   23,
#   25,
#   7,
#   392,
#   22,
#   2434,
#   1343,
#   26,
#   13,
#   41,
#   247,
#   4,
#   27,
#   707,
#   23,
#   17,
#   471,
#   30,
#   9,
#   17,
#   98,
#   317,
#   10,
#   6,
#   16,
#   28,
#   18,
#   172,
#   23,
#   4,
#   27,
#   471,
#   30,
#   5,
#   366,
#   2071,
#   23,
#   3,
#   1044,
#   99,
#   21,
#   40,
#   12,
#   454,
#   1405,
#   5,
#   56,
#   2,
#   869,
#   3,
#   118,
#   33,
#   40,
#   19,
#   7,
#   49,
#   9,
#   830,
#   127,
#   276,
#   18,
#   31,
#   14,
#   4215,
#   9,
#   743,
#   5,
#   31,
#   1288,
#   20,
#   303,
#   6,
#   16,
#   28,
#   416,
#   123,
#   4669],
#  [24,
#   979,
#   764,
#   1299,
#   72,
#   6,
#   1262,
#   10,
#   151,
#   46,
#   94,
#   7,
#   49,
#   24,
#   24,
#   1057,
#   154,
#   427,
#   3,
#   173,
#   562,
#   4,
#   601,
#   2,
#   96,
#   13,
#   68,
#   5,
#   2602,
#   393],
#  [77,
#   31,
#   202,
#   253,
#   10,
#   6,
#   16,
#   28,
#   9,
#   3,
#   15,
#   38,
#   438,
#   8,
#   13,
#   11,
#   7,
#   7,
#   396,
#   8,
#   5989,
#   29,
#   34,
#   341],
#  [3,
#   35,
#   6,
#   5200,
#   698,
#   10,
#   1034,
#   12,
#   3438,
#   10,
#   1034,
#   3,
#   130,
#   4,
#   5,
#   4,
#   801,
#   5,
#   1058,
#   8,
#   2,
#   2531,
#   259,
#   71,
#   3,
#   15,
#   1974,
#   1,
#   12,
#   265,
#   6260,
#   10,
#   1034,
#   801,
#   69,
#   4,
#   20,
#   7,
#   719,
#   86,
#   248,
#   9,
#   3,
#   175,
#   4,
#   15,
#   1703,
#   26,
#   131,
#   24,
#   6,
#   338,
#   22,
#   66,
#   3,
#   11,
#   46,
#   7,
#   385,
#   3769,
#   102,
#   46,
#   7,
#   4,
#   88,
#   34,
#   844,
#   102,
#   84,
#   4,
#   2,
#   385,
#   272,
#   12,
#   135,
#   2287,
#   46,
#   3,
#   11,
#   186,
#   635,
#   2168,
#   4,
#   120,
#   7,
#   1704,
#   5,
#   3655,
#   3,
#   45,
#   67,
#   120,
#   19,
#   215,
#   7,
#   1,
#   34,
#   93,
#   1050,
#   3943,
#   2,
#   9810,
#   50,
#   3,
#   63,
#   14,
#   3221,
#   29,
#   1139,
#   7446,
#   105,
#   1742,
#   3,
#   111,
#   504,
#   19,
#   801,
#   4,
#   1455,
#   2534,
#   26,
#   19,
#   9,
#   168,
#   5,
#   9,
#   11,
#   23,
#   296,
#   9,
#   168,
#   801,
#   237,
#   4,
#   1455,
#   681,
#   26,
#   102,
#   81,
#   296,
#   2279,
#   26,
#   6,
#   54,
#   659,
#   801,
#   4,
#   1455,
#   2534,
#   26,
#   5,
#   102,
#   1703,
#   26,
#   50,
#   1,
#   3,
#   67,
#   536,
#   8,
#   75,
#   3,
#   214,
#   7,
#   139,
#   4,
#   5869,
#   2,
#   681,
#   26,
#   5,
#   2,
#   2279,
#   26,
#   120,
#   62,
#   2006,
#   5,
#   6,
#   54,
#   294,
#   20,
#   266,
#   4,
#   1365,
#   577,
#   3,
#   67,
#   536,
#   3,
#   56,
#   14,
#   15,
#   37,
#   174,
#   104,
#   12,
#   6,
#   338,
#   22,
#   75,
#   1285,
#   26,
#   11,
#   2006,
#   4,
#   5,
#   801,
#   50,
#   369,
#   2,
#   1809,
#   5,
#   449,
#   40,
#   10,
#   6,
#   698,
#   465,
#   265,
#   819,
#   156,
#   6,
#   8115,
#   52,
#   65,
#   9,
#   3,
#   118,
#   38,
#   529,
#   1975,
#   29,
#   1172,
#   109,
#   35,
#   562,
#   265,
#   819,
#   15,
#   14,
#   175,
#   19,
#   78,
#   10,
#   479,
#   465,
#   698,
#   123,
#   127,
#   458,
#   6,
#   16,
#   211,
#   310,
#   9,
#   3,
#   110,
#   307,
#   265,
#   819,
#   41,
#   14,
#   175,
#   19,
#   6,
#   1187,
#   43,
#   127,
#   458,
#   3,
#   1008,
#   34,
#   93,
#   4,
#   27,
#   91,
#   107,
#   6,
#   2736,
#   57,
#   41,
#   681,
#   26,
#   10,
#   23,
#   379,
#   23,
#   56,
#   14,
#   484,
#   4,
#   2,
#   2531,
#   73,
#   536,
#   34,
#   943,
#   10,
#   57,
#   75,
#   23,
#   35,
#   320,
#   1181,
#   20,
#   472,
#   7,
#   168,
#   1514,
#   3,
#   15,
#   265,
#   669,
#   3,
#   15,
#   14,
#   53,
#   37,
#   206,
#   12,
#   713,
#   4,
#   6,
#   49,
#   479,
#   24,
#   479,
#   55,
#   3,
#   63,
#   14,
#   15,
#   6,
#   2306,
#   2030,
#   4,
#   221,
#   29,
#   142,
#   287,
#   65,
#   109,
#   80,
#   3,
#   63,
#   1277],
#  [3,
#   15,
#   34,
#   884,
#   22,
#   24,
#   3,
#   35,
#   749,
#   219,
#   13,
#   22,
#   3,
#   15,
#   67,
#   305,
#   197,
#   21,
#   726,
#   4,
#   2,
#   212,
#   49,
#   92,
#   387,
#   157,
#   706,
#   312,
#   425,
#   208,
#   314,
#   1952,
#   3,
#   95,
#   2,
#   998,
#   8,
#   2,
#   49,
#   7339,
#   3,
#   307,
#   3,
#   120,
#   9,
#   145,
#   325,
#   8,
#   2,
#   227,
#   167,
#   2,
#   177,
#   378,
#   29,
#   262,
#   117,
#   37,
#   5,
#   44,
#   493,
#   1421,
#   627,
#   4,
#   13,
#   49,
#   125,
#   37,
#   5,
#   44,
#   346,
#   1735,
#   251,
#   37,
#   5,
#   44,
#   1242,
#   805,
#   273,
#   177,
#   103,
#   8,
#   1005,
#   5,
#   92,
#   620,
#   1431,
#   426,
#   1032,
#   39,
#   656,
#   2,
#   49,
#   5,
#   64,
#   65,
#   2,
#   93,
#   91,
#   19,
#   2,
#   49,
#   502,
#   2,
#   103,
#   208,
#   2,
#   49,
#   1421,
#   2061,
#   723,
#   34,
#   4122,
#   8,
#   2,
#   1473,
#   469,
#   34,
#   1543,
#   19,
#   37,
#   424,
#   181,
#   223,
#   29,
#   135,
#   266,
#   449,
#   10,
#   13,
#   22,
#   3,
#   235,
#   4,
#   120,
#   9,
#   960,
#   5,
#   1411,
#   44,
#   421,
#   1474,
#   5,
#   92,
#   8664,
#   5,
#   145,
#   2,
#   325,
#   8,
#   2,
#   4328,
#   49,
#   89,
#   73,
#   783,
#   2,
#   1305,
#   132,
#   130,
#   2,
#   356,
#   230,
#   273,
#   81,
#   75,
#   549,
#   13,
#   95,
#   5,
#   557,
#   34,
#   844,
#   1941,
#   129,
#   1707,
#   8,
#   2258,
#   8,
#   325,
#   584,
#   24,
#   7,
#   240,
#   46,
#   9,
#   1305,
#   506,
#   4,
#   2,
#   212,
#   16,
#   42,
#   157,
#   171,
#   976,
#   7,
#   167,
#   7,
#   82,
#   55,
#   17,
#   340,
#   33,
#   281,
#   201,
#   4,
#   299,
#   141,
#   2,
#   1001,
#   325,
#   8,
#   2,
#   177,
#   346,
#   430,
#   70,
#   262,
#   8,
#   37,
#   5,
#   44,
#   52,
#   39,
#   120,
#   4,
#   27,
#   788,
#   5,
#   29,
#   130,
#   10,
#   7,
#   16,
#   28,
#   3,
#   534,
#   4,
#   148,
#   7,
#   209,
#   8,
#   2,
#   780,
#   1142,
#   144,
#   34,
#   177,
#   70,
#   262,
#   21,
#   7,
#   3090,
#   3506,
#   451,
#   10,
#   23,
#   724,
#   8,
#   724,
#   31,
#   14,
#   402,
#   5,
#   33,
#   201,
#   31,
#   14,
#   1152,
#   144,
#   9,
#   39,
#   15,
#   10,
#   116,
#   19,
#   2,
#   22,
#   253,
#   476,
#   129,
#   2,
#   229,
#   884,
#   1112,
#   52,
#   254,
#   27,
#   131,
#   64,
#   39,
#   31,
#   420,
#   4,
#   145,
#   2,
#   20,
#   21,
#   7,
#   209,
#   8,
#   2,
#   780,
#   1142,
#   144,
#   9,
#   39,
#   15,
#   10,
#   116,
#   230,
#   185,
#   3408,
#   81,
#   24,
#   537,
#   8,
#   13,
#   232,
#   19,
#   2,
#   22,
#   253,
#   476,
#   102,
#   39,
#   254,
#   46,
#   350,
#   133,
#   2,
#   22,
#   24,
#   82,
#   124,
#   16,
#   211,
#   3,
#   534,
#   2,
#   22,
#   27,
#   295,
#   29,
#   131,
#   200,
#   2,
#   201,
#   17,
#   243,
#   604,
#   25,
#   4,
#   2,
#   901,
#   1674,
#   5,
#   2,
#   1646,
#   552,
#   4,
#   20,
#   19,
#   2,
#   1919,
#   2868,
#   113,
#   171,
#   2910,
#   64,
#   39,
#   1369,
#   4,
#   882,
#   21,
#   13,
#   281,
#   201,
#   82,
#   758,
#   4,
#   2323,
#   299,
#   61,
#   52,
#   41,
#   1388,
#   6,
#   795,
#   4,
#   557,
#   16,
#   129,
#   2,
#   229,
#   884,
#   52,
#   254,
#   27,
#   131,
#   5,
#   64,
#   39,
#   31,
#   420,
#   4,
#   145,
#   20,
#   7,
#   209,
#   8,
#   780,
#   144,
#   39,
#   254,
#   133,
#   2,
#   52,
#   253,
#   370,
#   3,
#   534,
#   2,
#   227,
#   52,
#   27,
#   295,
#   29,
#   131,
#   200],
#  [506,
#   4,
#   2,
#   212,
#   16,
#   42,
#   157,
#   171,
#   976,
#   7,
#   167,
#   7,
#   39,
#   31,
#   340,
#   33,
#   281,
#   201,
#   4,
#   299,
#   141,
#   2,
#   1001,
#   325,
#   8,
#   2,
#   177,
#   346,
#   70,
#   262,
#   37,
#   5,
#   44,
#   52,
#   39,
#   941,
#   10,
#   7,
#   16,
#   28,
#   666,
#   546,
#   362,
#   19,
#   82,
#   42,
#   244,
#   118,
#   609,
#   206,
#   29,
#   161,
#   12,
#   7,
#   140,
#   22,
#   3,
#   534,
#   4,
#   148,
#   780,
#   144,
#   34,
#   177,
#   70,
#   262,
#   21,
#   6,
#   451,
#   10,
#   23,
#   39,
#   15,
#   10,
#   116,
#   8,
#   2,
#   52,
#   253,
#   370,
#   82,
#   758,
#   4,
#   2323,
#   299,
#   61,
#   52,
#   41,
#   1388,
#   6,
#   795,
#   4,
#   557,
#   16,
#   129,
#   2,
#   229,
#   884,
#   52,
#   254,
#   27,
#   131,
#   5,
#   64,
#   39,
#   31,
#   420,
#   4,
#   145,
#   20,
#   7,
#   209,
#   8,
#   780,
#   144,
#   39,
#   254,
#   133,
#   2,
#   52,
#   253,
#   370],
#  [3489,
#   4,
#   3060,
#   26,
#   488,
#   333,
#   90,
#   3826,
#   26,
#   561,
#   692,
#   4,
#   1393,
#   1620,
#   5,
#   1585,
#   2807,
#   19,
#   125,
#   517,
#   47,
#   15,
#   4,
#   133,
#   575,
#   24,
#   2,
#   1,
#   83,
#   4,
#   588,
#   1780,
#   256,
#   141,
#   663,
#   1386,
#   4,
#   32,
#   23,
#   79,
#   5,
#   536,
#   4,
#   63,
#   65,
#   3,
#   15,
#   67,
#   53,
#   7,
#   146,
#   363,
#   317,
#   6,
#   451,
#   10,
#   85,
#   67,
#   53,
#   7,
#   146,
#   19,
#   1015,
#   90,
#   363,
#   1416,
#   7,
#   146,
#   927,
#   771,
#   2,
#   104,
#   927,
#   488,
#   1721,
#   4,
#   528,
#   1015,
#   258,
#   19,
#   167,
#   5541,
#   35,
#   20,
#   342,
#   9,
#   3,
#   45,
#   14,
#   307,
#   284,
#   71,
#   3,
#   56,
#   7,
#   663,
#   32,
#   23,
#   79,
#   83,
#   4,
#   3876,
#   41,
#   8815,
#   36,
#   1101,
#   6,
#   16,
#   123,
#   77,
#   111,
#   980,
#   31,
#   927,
#   2055,
#   1585,
#   51,
#   1585,
#   83,
#   4,
#   927,
#   2055,
#   488,
#   5,
#   2265,
#   5572,
#   1585,
#   51,
#   1585,
#   83,
#   4,
#   7,
#   5572,
#   735,
#   153,
#   1620,
#   148,
#   370,
#   19,
#   174,
#   683,
#   6378,
#   51,
#   1620,
#   148,
#   370,
#   19,
#   174,
#   683,
#   5,
#   174,
#   51,
#   1585,
#   51,
#   1585,
#   378,
#   927,
#   2055,
#   51,
#   1585,
#   378,
#   1488,
#   407,
#   51,
#   1585,
#   378,
#   471,
#   2741,
#   795,
#   4,
#   1357,
#   51,
#   1585,
#   378,
#   471,
#   2741,
#   1,
#   349,
#   51,
#   1585,
#   378,
#   471,
#   2741,
#   523,
#   451,
#   43,
#   335,
#   3527,
#   186,
#   2482,
#   8,
#   590,
#   76,
#   3,
#   214,
#   19,
#   335,
#   12,
#   5,
#   23,
#   1189,
#   12,
#   3527,
#   186,
#   2482,
#   8,
#   590,
#   76,
#   5,
#   1,
#   85,
#   8,
#   2,
#   9165,
#   4975,
#   462,
#   51,
#   2726,
#   41,
#   1044,
#   7,
#   462,
#   51,
#   1620,
#   1029],
#  [3,
#   247,
#   6,
#   16,
#   28,
#   8,
#   44,
#   125,
#   16,
#   297,
#   10,
#   1,
#   32,
#   192,
#   5,
#   3,
#   308,
#   355,
#   341,
#   12,
#   44,
#   125,
#   16,
#   297,
#   50,
#   3,
#   45,
#   183,
#   39,
#   4,
#   159,
#   20,
#   2147,
#   3,
#   320,
#   95,
#   13,
#   30,
#   5,
#   127,
#   199,
#   40,
#   3294,
#   4,
#   2,
#   16,
#   137,
#   5,
#   18,
#   15,
#   14,
#   305,
#   284,
#   4,
#   250,
#   13,
#   30,
#   50,
#   17,
#   1101,
#   6,
#   16,
#   381],
#  [10,
#   3,
#   69,
#   7,
#   76,
#   4,
#   4009,
#   3959,
#   71,
#   18,
#   1444,
#   10,
#   6,
#   16,
#   18,
#   56,
#   14,
#   533,
#   4,
#   9,
#   76,
#   21,
#   402,
#   8,
#   2,
#   49,
#   238,
#   18,
#   31,
#   14,
#   2,
#   16,
#   137,
#   18,
#   63,
#   14,
#   15,
#   1856,
#   81,
#   4,
#   533,
#   4,
#   7,
#   95,
#   183,
#   2,
#   16,
#   137,
#   63,
#   18,
#   15,
#   185,
#   81,
#   24,
#   2,
#   103,
#   8,
#   2,
#   120,
#   19,
#   402,
#   25,
#   357,
#   2,
#   706,
#   18,
#   15,
#   336,
#   42,
#   1286,
#   71,
#   18,
#   31,
#   2,
#   22,
#   4003,
#   64,
#   18,
#   118,
#   14,
#   145,
#   402,
#   4,
#   20,
#   230,
#   185,
#   81,
#   8,
#   2,
#   120,
#   25,
#   2,
#   499,
#   390,
#   18,
#   254,
#   265,
#   133,
#   2,
#   22,
#   5,
#   960,
#   5,
#   1411,
#   44,
#   92,
#   620,
#   18,
#   15,
#   761,
#   2,
#   229,
#   5,
#   706,
#   5,
#   3,
#   235,
#   2654],
#  [10,
#   143,
#   3,
#   326,
#   19,
#   7,
#   714,
#   51,
#   21,
#   6,
#   169,
#   333,
#   108,
#   55,
#   879,
#   4,
#   88,
#   7,
#   1073,
#   181,
#   459,
#   5,
#   4,
#   73,
#   88,
#   3877,
#   8,
#   408,
#   4,
#   100,
#   1435,
#   292,
#   302,
#   484,
#   4,
#   1238,
#   4,
#   2,
#   714,
#   51,
#   6,
#   16,
#   193,
#   11,
#   253,
#   46,
#   94,
#   1,
#   141,
#   265,
#   5,
#   73,
#   50,
#   17,
#   552,
#   4,
#   20,
#   141,
#   16,
#   57,
#   75,
#   2,
#   460,
#   213,
#   113,
#   16,
#   146,
#   11,
#   305,
#   3,
#   53,
#   34,
#   574,
#   9,
#   6,
#   16,
#   193,
#   35,
#   636,
#   46,
#   13,
#   68,
#   3,
#   11,
#   1401,
#   4,
#   148,
#   9,
#   6,
#   193,
#   920,
#   7,
#   8507,
#   4329,
#   599,
#   29,
#   65,
#   4,
#   7,
#   193,
#   8,
#   339,
#   677,
#   2,
#   139,
#   71,
#   13,
#   41,
#   247,
#   4,
#   27,
#   1152,
#   34,
#   32,
#   2042,
#   1383,
#   5,
#   3,
#   80,
#   14,
#   342,
#   9,
#   77,
#   31,
#   38,
#   1241,
#   25,
#   4,
#   155,
#   500,
#   2,
#   42,
#   136,
#   80,
#   1383,
#   82,
#   193,
#   19,
#   7,
#   16,
#   213,
#   3,
#   48,
#   1099,
#   1401,
#   71,
#   13,
#   17,
#   7,
#   714,
#   8,
#   2,
#   169,
#   51,
#   93,
#   5,
#   19,
#   7,
#   7978,
#   1267,
#   565,
#   23,
#   17,
#   3236,
#   4,
#   20,
#   9,
#   61,
#   42,
#   280,
#   31,
#   14,
#   845,
#   174,
#   1643,
#   89,
#   1475,
#   7538],
#  [32,
#   192,
#   5,
#   31,
#   42,
#   184,
#   5,
#   471,
#   30,
#   10,
#   6,
#   16,
#   28,
#   32,
#   192,
#   17,
#   42,
#   2834,
#   9,
#   149,
#   45,
#   131,
#   5,
#   317,
#   84,
#   10,
#   3,
#   15,
#   73,
#   67,
#   1060,
#   46,
#   2834,
#   41,
#   130,
#   9,
#   34,
#   22,
#   19,
#   21,
#   207,
#   103,
#   130,
#   32,
#   192,
#   5,
#   1469,
#   400,
#   854,
#   30,
#   19,
#   2,
#   22,
#   2506,
#   38,
#   90,
#   38,
#   755,
#   16,
#   565,
#   2,
#   103,
#   8,
#   207,
#   620,
#   19,
#   32,
#   192,
#   17,
#   5,
#   17,
#   298,
#   2,
#   571,
#   8,
#   207,
#   1188,
#   25,
#   10,
#   155,
#   80,
#   9,
#   27,
#   64,
#   3,
#   214,
#   335,
#   154,
#   427,
#   21,
#   13,
#   22,
#   32,
#   192,
#   5,
#   1469,
#   15,
#   854,
#   30,
#   94,
#   2,
#   2262,
#   4611,
#   114,
#   571,
#   8,
#   207,
#   620,
#   31,
#   44,
#   1912,
#   443,
#   99,
#   2506,
#   38,
#   30,
#   94,
#   2,
#   16,
#   565,
#   29,
#   284,
#   17,
#   298,
#   9,
#   2,
#   22,
#   21,
#   11,
#   207,
#   1188,
#   10,
#   13,
#   17,
#   324,
#   17,
#   298,
#   207,
#   1188,
#   8,
#   5,
#   1469,
#   400,
#   90,
#   19,
#   1469,
#   400,
#   37,
#   30,
#   10,
#   43,
#   349,
#   29,
#   16,
#   565,
#   77,
#   260,
#   298,
#   109,
#   668,
#   8,
#   22,
#   23,
#   17,
#   44,
#   13,
#   30,
#   1469,
#   1227,
#   183,
#   23,
#   41,
#   36,
#   295,
#   71,
#   2506,
#   65,
#   500,
#   922,
#   30,
#   32,
#   192,
#   496,
#   9,
#   2,
#   22,
#   1226,
#   152,
#   10,
#   5,
#   5,
#   400,
#   103,
#   152,
#   10,
#   109,
#   30,
#   17,
#   344,
#   17,
#   9344,
#   25,
#   267,
#   22,
#   668,
#   47,
#   2,
#   22,
#   349,
#   640,
#   156,
#   2,
#   52,
#   73,
#   400,
#   9,
#   2506,
#   38,
#   755,
#   16,
#   565,
#   47,
#   2506,
#   7,
#   90,
#   83,
#   8,
#   4156,
#   26,
#   155,
#   80,
#   9,
#   27,
#   103,
#   207,
#   1188,
#   17,
#   324,
#   25,
#   190,
#   17,
#   298,
#   19,
#   324,
#   5,
#   922,
#   30,
#   2506,
#   38,
#   90,
#   19,
#   38,
#   755,
#   16,
#   565,
#   38,
#   16,
#   565,
#   496,
#   22,
#   349,
#   25,
#   135,
#   47,
#   32,
#   192,
#   496,
#   25,
#   156,
#   32,
#   192,
#   73,
#   41,
#   2,
#   22,
#   25,
#   207,
#   130,
#   10,
#   5,
#   7,
#   496,
#   109,
#   17,
#   250,
#   180,
#   17,
#   44,
#   2,
#   30,
#   42,
#   4079,
#   17,
#   298,
#   19,
#   9,
#   2,
#   22,
#   17,
#   1,
#   132,
#   17,
#   1311,
#   13,
#   30,
#   2,
#   22,
#   668,
#   17,
#   554,
#   3528,
#   755,
#   16,
#   565,
#   17,
#   554,
#   3528,
#   77,
#   17,
#   635,
#   500,
#   30,
#   554,
#   3528,
#   17,
#   2071,
#   9,
#   3,
#   15,
#   117,
#   1210,
#   867,
#   5,
#   85,
#   1210,
#   867,
#   18,
#   31,
#   44,
#   922,
#   30,
#   849,
#   581,
#   31,
#   419,
#   19,
#   2,
#   867,
#   18,
#   73,
#   31,
#   380,
#   3,
#   214,
#   46,
#   179,
#   1790,
#   328,
#   9,
#   17,
#   324,
#   2,
#   349,
#   17,
#   922,
#   2,
#   103,
#   1044,
#   17,
#   922,
#   2,
#   1674,
#   841,
#   31,
#   922,
#   19,
#   228,
#   298,
#   9,
#   3,
#   214,
#   7,
#   867,
#   46,
#   2793,
#   132,
#   17,
#   2793,
#   13,
#   30,
#   17,
#   184,
#   2,
#   103,
#   1044,
#   19,
#   2,
#   1,
#   31,
#   324,
#   32,
#   192,
#   496,
#   44,
#   184,
#   22,
#   849,
#   581,
#   571,
#   1,
#   31,
#   324,
#   44,
#   61,
#   52,
#   31,
#   12,
#   288,
#   8,
#   2,
#   229,
#   18,
#   15,
#   39,
#   145,
#   20,
#   21,
#   155,
#   18,
#   295,
#   37,
#   8,
#   13,
#   30,
#   50,
#   4080,
#   20,
#   4,
#   342,
#   9,
#   18,
#   31,
#   14,
#   1,
#   938,
#   2056,
#   29,
#   227,
#   102,
#   1093,
#   29,
#   1,
#   499,
#   89,
#   15,
#   40,
#   133,
#   44,
#   2,
#   52,
#   253,
#   370,
#   24,
#   257,
#   1511,
#   28,
#   1277],
#  [1782,
#   22,
#   3891,
#   26,
#   466,
#   1815,
#   5,
#   3211,
#   5,
#   1401,
#   66,
#   3,
#   748,
#   6,
#   16,
#   28,
#   13,
#   530,
#   5,
#   3,
#   308,
#   319,
#   1064,
#   10,
#   6,
#   16,
#   28,
#   24,
#   2,
#   125,
#   825,
#   16,
#   137,
#   24,
#   7,
#   92,
#   55,
#   9,
#   3,
#   67,
#   15,
#   2392,
#   21,
#   231,
#   376,
#   579,
#   176,
#   147,
#   4,
#   4670,
#   2,
#   191,
#   21,
#   2,
#   177,
#   590,
#   5,
#   16,
#   137,
#   5,
#   18,
#   110,
#   42,
#   184,
#   1304,
#   30,
#   3,
#   15,
#   219,
#   13,
#   356,
#   21,
#   2,
#   16,
#   42,
#   136,
#   5,
#   18,
#   130,
#   39,
#   633,
#   2,
#   22,
#   25,
#   675,
#   3,
#   2237,
#   63,
#   14,
#   342,
#   4,
#   416,
#   15,
#   37,
#   904,
#   21,
#   13,
#   92,
#   136,
#   29,
#   177,
#   210,
#   73,
#   77,
#   31,
#   176,
#   1064,
#   21,
#   13,
#   22,
#   2,
#   315,
#   550,
#   42,
#   5,
#   1106,
#   7,
#   488,
#   288,
#   8,
#   229,
#   5,
#   706,
#   499,
#   5,
#   1040,
#   12,
#   7,
#   454,
#   1405,
#   1384,
#   4,
#   367,
#   2,
#   245,
#   3554,
#   3,
#   254,
#   534,
#   144,
#   8,
#   13,
#   49,
#   1023,
#   2,
#   306,
#   262,
#   29,
#   135,
#   1791,
#   1067,
#   6,
#   451,
#   25,
#   190,
#   25,
#   144,
#   8,
#   82,
#   1068,
#   12,
#   13,
#   245,
#   3615,
#   215,
#   144,
#   39,
#   254,
#   250,
#   37,
#   847,
#   211,
#   8,
#   13,
#   239,
#   49,
#   25,
#   276,
#   3,
#   48,
#   394,
#   4,
#   120,
#   9,
#   39,
#   89,
#   145,
#   2,
#   227,
#   30,
#   167,
#   89,
#   450,
#   82,
#   665,
#   129,
#   312,
#   781,
#   1686,
#   32,
#   5,
#   312,
#   781,
#   1686,
#   680,
#   12,
#   13,
#   306,
#   245,
#   117,
#   109,
#   17,
#   82,
#   665,
#   8,
#   201,
#   19,
#   82,
#   92,
#   8,
#   30,
#   125,
#   109,
#   17,
#   82,
#   665,
#   8,
#   201,
#   19,
#   82,
#   92,
#   8,
#   13,
#   306,
#   49,
#   251,
#   89,
#   450,
#   82,
#   665,
#   4,
#   63,
#   197,
#   29,
#   2579,
#   12,
#   13,
#   310,
#   273,
#   89,
#   450,
#   144,
#   8,
#   2,
#   306,
#   49,
#   469,
#   2,
#   306,
#   262,
#   29,
#   135,
#   1791,
#   1067,
#   6,
#   451,
#   426,
#   89,
#   145,
#   7,
#   441,
#   22,
#   381,
#   469,
#   37,
#   223,
#   594,
#   19,
#   92,
#   620,
#   39,
#   15,
#   185,
#   81,
#   464,
#   537,
#   8,
#   13,
#   76,
#   4,
#   145,
#   2829,
#   144,
#   8,
#   262,
#   12,
#   2,
#   1624,
#   39,
#   80,
#   14,
#   145,
#   2829,
#   144,
#   8,
#   262,
#   39,
#   254,
#   960,
#   5,
#   1411,
#   37,
#   5,
#   44,
#   92,
#   1331,
#   5,
#   200,
#   133,
#   37,
#   586,
#   30,
#   130,
#   4,
#   2,
#   70,
#   42,
#   280,
#   12,
#   728,
#   39,
#   74,
#   160,
#   4,
#   145,
#   20,
#   82,
#   359,
#   12,
#   394,
#   9,
#   39,
#   31,
#   511,
#   82,
#   116,
#   4216,
#   1320,
#   620,
#   5,
#   2754,
#   44,
#   30,
#   627,
#   4,
#   13,
#   849,
#   86,
#   24,
#   37,
#   5,
#   44,
#   16,
#   211,
#   3397,
#   1555,
#   2,
#   30,
#   4,
#   12,
#   2,
#   1624,
#   39,
#   358,
#   13,
#   22,
#   4,
#   34,
#   444,
#   182,
#   792,
#   144,
#   8,
#   262,
#   5,
#   1540,
#   82,
#   163,
#   114,
#   106,
#   74,
#   27,
#   1353,
#   130,
#   4,
#   2,
#   5,
#   19,
#   709,
#   8,
#   3897,
#   846],
#  [61,
#   31,
#   14,
#   6,
#   52,
#   3,
#   15,
#   69,
#   430,
#   206,
#   337,
#   1781,
#   8,
#   49,
#   842,
#   8,
#   325,
#   5,
#   402,
#   8,
#   49,
#   3,
#   11,
#   14,
#   851,
#   19,
#   7,
#   189,
#   24,
#   32,
#   3591,
#   368,
#   550,
#   36,
#   105,
#   3926,
#   21,
#   38,
#   189,
#   52],
#  [642,
#   1107,
#   966,
#   108,
#   22,
#   1199,
#   386,
#   126,
#   108,
#   17,
#   21,
#   642,
#   1107,
#   829,
#   5,
#   60,
#   15,
#   67,
#   1657,
#   10,
#   37,
#   78,
#   123,
#   2,
#   22,
#   11,
#   489,
#   4,
#   40,
#   463,
#   126,
#   16,
#   369,
#   7,
#   1594,
#   1230,
#   71,
#   642,
#   1107,
#   1565,
#   843,
#   9,
#   60,
#   15,
#   14,
#   91,
#   126,
#   1696,
#   5,
#   130,
#   23,
#   4,
#   16,
#   42,
#   280,
#   3268,
#   19,
#   2,
#   435,
#   13,
#   17,
#   7,
#   2848,
#   1470,
#   43,
#   19,
#   2,
#   108,
#   1696,
#   12,
#   699,
#   11,
#   87,
#   10,
#   19,
#   1703,
#   26,
#   141,
#   22,
#   5,
#   10,
#   19,
#   1306,
#   26,
#   141,
#   22,
#   89,
#   148,
#   224,
#   218,
#   19,
#   325,
#   25,
#   39,
#   80,
#   148,
#   1244,
#   1696,
#   24,
#   642,
#   1107,
#   67,
#   1694,
#   78,
#   87,
#   10,
#   5,
#   13,
#   17,
#   140,
#   129,
#   1683,
#   1731,
#   362,
#   3656,
#   231,
#   2,
#   83,
#   103,
#   122,
#   27,
#   5727,
#   5,
#   14,
#   2877,
#   567,
#   13,
#   4061,
#   2476,
#   5,
#   3810,
#   341,
#   551,
#   33,
#   642,
#   1107,
#   876,
#   12,
#   5299,
#   1,
#   10,
#   126,
#   16,
#   963,
#   5,
#   10,
#   126,
#   43,
#   381,
#   13,
#   17,
#   809,
#   5,
#   23,
#   515,
#   4,
#   27,
#   3286,
#   200,
#   13,
#   11,
#   2,
#   169,
#   387,
#   305,
#   33,
#   126,
#   578,
#   108,
#   55,
#   60,
#   31,
#   2072,
#   99,
#   21,
#   140,
#   387,
#   33,
#   61,
#   1,
#   309,
#   593,
#   10,
#   2,
#   476,
#   30,
#   5,
#   2,
#   224,
#   1116,
#   218,
#   39,
#   80,
#   637,
#   148,
#   9,
#   126,
#   1696,
#   11,
#   91,
#   5,
#   23,
#   11,
#   127,
#   91,
#   1605,
#   8,
#   2,
#   83,
#   103,
#   60,
#   100,
#   667,
#   8,
#   126,
#   615,
#   1605,
#   8,
#   2,
#   83,
#   103,
#   5,
#   14,
#   350,
#   15,
#   60,
#   35,
#   37,
#   973,
#   21,
#   135,
#   309,
#   1359,
#   60,
#   88,
#   16,
#   19,
#   883,
#   43,
#   13,
#   17,
#   2,
#   111,
#   55,
#   9,
#   1,
#   39,
#   19,
#   362,
#   82,
#   241,
#   1605,
#   8,
#   2,
#   83,
#   103,
#   855,
#   13,
#   30,
#   126,
#   1696,
#   11,
#   970,
#   91,
#   10,
#   68,
#   5,
#   540,
#   60,
#   63,
#   14,
#   307,
#   37,
#   97,
#   266,
#   25,
#   190,
#   60,
#   1144,
#   9,
#   677,
#   34,
#   1639,
#   139,
#   21,
#   82,
#   6101,
#   74,
#   159,
#   1260,
#   236,
#   1072,
#   8,
#   650,
#   4,
#   61,
#   6379,
#   2288,
#   140,
#   387,
#   33,
#   642,
#   1107,
#   5,
#   2,
#   1744,
#   18,
#   15,
#   551,
#   4,
#   6716,
#   612,
#   183,
#   179,
#   2401,
#   7447,
#   126,
#   16,
#   3,
#   342,
#   18,
#   122,
#   27,
#   1089,
#   4,
#   6717,
#   2,
#   334,
#   28,
#   69,
#   4,
#   2,
#   16,
#   42,
#   280,
#   3268,
#   21,
#   34,
#   1639,
#   4157,
#   76,
#   3,
#   725,
#   4,
#   1108,
#   24,
#   39,
#   1932,
#   440,
#   39,
#   19,
#   82,
#   68],
#  [25,
#   8,
#   3,
#   152,
#   34,
#   22,
#   21,
#   852,
#   54,
#   10,
#   7,
#   5367,
#   275,
#   4010,
#   43,
#   262,
#   6102,
#   127,
#   78,
#   38,
#   266,
#   5,
#   38,
#   181,
#   3194,
#   38,
#   97,
#   78,
#   75,
#   6213,
#   97,
#   266,
#   3,
#   7090,
#   21,
#   7,
#   271,
#   10,
#   261,
#   6,
#   90,
#   5,
#   266,
#   5,
#   11,
#   351,
#   9,
#   410,
#   6,
#   1300,
#   1312,
#   43,
#   357,
#   262,
#   266,
#   45,
#   27,
#   920,
#   5,
#   6,
#   343,
#   90,
#   45,
#   528,
#   4,
#   25,
#   405,
#   10,
#   262,
#   3913,
#   6,
#   22,
#   11,
#   67,
#   817,
#   2823,
#   5,
#   3,
#   638,
#   4,
#   221,
#   97,
#   43,
#   493,
#   10,
#   3,
#   249,
#   21,
#   7,
#   271,
#   132,
#   290,
#   20,
#   3,
#   35,
#   36,
#   4893,
#   5,
#   983,
#   20,
#   34,
#   1726,
#   220,
#   45,
#   27,
#   152,
#   261,
#   2,
#   271,
#   132,
#   1538,
#   6,
#   22,
#   10,
#   5,
#   122,
#   18,
#   403,
#   3,
#   11,
#   4893,
#   58,
#   84,
#   1442,
#   113,
#   45,
#   3126,
#   6,
#   22,
#   25,
#   5018,
#   75,
#   549,
#   38,
#   806,
#   3,
#   138,
#   852,
#   10,
#   6,
#   43,
#   83,
#   103,
#   4,
#   142,
#   6,
#   43,
#   5,
#   1366,
#   6,
#   220,
#   3,
#   11,
#   290,
#   10,
#   33,
#   9,
#   6,
#   220,
#   11,
#   3091,
#   10,
#   5,
#   18,
#   35,
#   308,
#   9,
#   2,
#   271,
#   3,
#   249,
#   21,
#   35,
#   14,
#   4893,
#   20,
#   646,
#   150,
#   3358],
#  [3,
#   48,
#   7,
#   1915,
#   2843,
#   24,
#   135,
#   627,
#   4,
#   3,
#   226,
#   6380,
#   5,
#   176,
#   135,
#   6380,
#   627,
#   4,
#   6,
#   8974,
#   31,
#   7,
#   1453,
#   1,
#   5,
#   6,
#   588,
#   17,
#   174,
#   225,
#   1195,
#   12,
#   1607,
#   4,
#   2,
#   473,
#   3,
#   2596,
#   24,
#   25,
#   7,
#   588,
#   60,
#   31,
#   732,
#   32,
#   2727,
#   233,
#   880,
#   6,
#   695,
#   5,
#   6,
#   869,
#   2064,
#   3646,
#   1486,
#   19,
#   20,
#   6,
#   869,
#   2064,
#   5,
#   6,
#   695,
#   138,
#   2,
#   113,
#   182,
#   6,
#   438,
#   3,
#   11,
#   1914,
#   8,
#   2,
#   2766,
#   19,
#   2,
#   159,
#   5,
#   3,
#   308,
#   79,
#   296,
#   6,
#   869,
#   2064,
#   91,
#   2,
#   3061,
#   26,
#   302,
#   4,
#   317,
#   12,
#   12,
#   178,
#   21,
#   7,
#   9,
#   1,
#   12,
#   5,
#   3,
#   11,
#   1,
#   21,
#   5,
#   176,
#   135,
#   1,
#   1,
#   24,
#   2287,
#   118,
#   14,
#   32,
#   738,
#   155,
#   1,
#   2,
#   5368,
#   87,
#   20,
#   645,
#   4,
#   1,
#   21,
#   109,
#   3,
#   15,
#   36,
#   32,
#   2727,
#   19,
#   5369,
#   6,
#   695,
#   132,
#   17,
#   14,
#   34,
#   697,
#   2164,
#   346,
#   20,
#   99,
#   21,
#   113,
#   12,
#   2507,
#   1352,
#   605,
#   159,
#   182,
#   6,
#   438,
#   19,
#   7,
#   2843,
#   703,
#   6,
#   695,
#   17,
#   14,
#   190,
#   1,
#   12,
#   2,
#   3247,
#   2127,
#   5,
#   56,
#   14,
#   970,
#   7159,
#   2,
#   1,
#   8,
#   2,
#   605,
#   3511,
#   113,
#   145,
#   3,
#   11,
#   290,
#   13,
#   1556,
#   340,
#   43,
#   24,
#   6,
#   1088,
#   1,
#   19,
#   2,
#   93,
#   8,
#   5425,
#   26,
#   5,
#   3,
#   11,
#   1,
#   2,
#   113,
#   31,
#   14,
#   7,
#   995,
#   536,
#   1556,
#   50,
#   6,
#   695,
#   11,
#   2312,
#   4,
#   342,
#   23,
#   11,
#   13,
#   1556,
#   17,
#   674,
#   441,
#   1021,
#   8,
#   1915,
#   150,
#   8116,
#   5,
#   23,
#   122,
#   27,
#   1339,
#   4,
#   170,
#   2883,
#   215,
#   7,
#   7010,
#   4291,
#   93,
#   8,
#   159,
#   19,
#   243,
#   1248,
#   244,
#   196,
#   3,
#   317,
#   12,
#   7,
#   95,
#   21,
#   32,
#   1,
#   3,
#   35,
#   14,
#   346,
#   284,
#   21,
#   13,
#   136,
#   19,
#   58,
#   244,
#   47,
#   6,
#   695,
#   715,
#   7,
#   1523,
#   10,
#   58,
#   1055,
#   5,
#   13,
#   384,
#   1,
#   20,
#   4,
#   7,
#   5425,
#   26,
#   3616,
#   182,
#   6,
#   746,
#   3,
#   48,
#   1,
#   4,
#   15,
#   13,
#   1459,
#   6042,
#   8,
#   6,
#   1511,
#   211,
#   89,
#   159,
#   20],
#  [374,
#   85,
#   17,
#   42,
#   7,
#   97,
#   43,
#   19,
#   143,
#   3,
#   15,
#   67,
#   36,
#   97,
#   10,
#   13,
#   22,
#   3,
#   15,
#   35,
#   23,
#   19,
#   355,
#   154,
#   3,
#   87,
#   6,
#   43,
#   10,
#   68,
#   10,
#   2,
#   793,
#   5,
#   3,
#   773,
#   23,
#   256,
#   141,
#   102,
#   3,
#   503,
#   296,
#   9,
#   23,
#   377,
#   65,
#   3,
#   7634,
#   5,
#   87,
#   23,
#   121,
#   10,
#   2,
#   793,
#   5,
#   3,
#   72,
#   39,
#   2136,
#   5,
#   351,
#   39,
#   9,
#   3,
#   35,
#   87,
#   23,
#   749,
#   5,
#   77,
#   11,
#   34,
#   191,
#   21,
#   2,
#   259,
#   793,
#   18,
#   983,
#   20,
#   9,
#   23,
#   11,
#   110,
#   10,
#   68,
#   5,
#   23,
#   11,
#   1235,
#   5,
#   9,
#   3,
#   1373,
#   15,
#   7,
#   97,
#   71,
#   18,
#   118,
#   148,
#   3,
#   87,
#   23,
#   10,
#   68,
#   13,
#   11,
#   14,
#   6,
#   341,
#   13,
#   11,
#   82,
#   368,
#   89,
#   133,
#   13,
#   97,
#   25,
#   3,
#   732,
#   56,
#   142,
#   6,
#   43,
#   10,
#   68],
#  [3,
#   15,
#   203,
#   462,
#   278,
#   10,
#   6,
#   22,
#   21,
#   640,
#   466,
#   670,
#   217,
#   2,
#   462,
#   278,
#   62,
#   489,
#   50,
#   15,
#   592,
#   36,
#   362,
#   119,
#   5,
#   17,
#   12,
#   454,
#   739,
#   13,
#   17,
#   3255,
#   20,
#   2755,
#   272,
#   64,
#   3279,
#   1,
#   50,
#   11,
#   267,
#   2890],
#  [3,
#   48,
#   394,
#   4,
#   985,
#   39,
#   94,
#   34,
#   341,
#   10,
#   6,
#   16,
#   28,
#   5,
#   120,
#   9,
#   39,
#   145,
#   20,
#   21,
#   780,
#   144,
#   29,
#   414,
#   2,
#   435,
#   200,
#   3,
#   48,
#   32,
#   3723,
#   6,
#   300,
#   129,
#   2,
#   212,
#   16,
#   42,
#   157,
#   171,
#   976,
#   4,
#   120,
#   30,
#   261,
#   34,
#   356,
#   9,
#   17,
#   253,
#   10,
#   6,
#   70,
#   16,
#   28,
#   25,
#   357,
#   2,
#   229,
#   111,
#   344,
#   5,
#   814,
#   30,
#   234,
#   27,
#   253,
#   10,
#   6,
#   16,
#   28,
#   171,
#   976,
#   8,
#   2,
#   229,
#   1545,
#   20,
#   2,
#   300,
#   4,
#   148,
#   109,
#   2,
#   328,
#   69,
#   4,
#   82,
#   16,
#   42,
#   136,
#   25,
#   450,
#   9,
#   2,
#   30,
#   17,
#   250,
#   335,
#   1189,
#   3527,
#   3,
#   308,
#   215,
#   2612,
#   12,
#   335,
#   12,
#   16,
#   28,
#   849,
#   86,
#   17,
#   324,
#   38,
#   178,
#   30,
#   64,
#   39,
#   31,
#   420,
#   4,
#   299,
#   2,
#   22,
#   2,
#   30,
#   122,
#   27,
#   131,
#   24,
#   6,
#   16,
#   28,
#   440,
#   39,
#   19,
#   82,
#   159],
#  [3,
#   69,
#   104,
#   4,
#   7,
#   2064,
#   458,
#   3187,
#   779,
#   10,
#   143,
#   12,
#   2,
#   93,
#   8,
#   2439,
#   642,
#   11,
#   712,
#   4,
#   221,
#   2,
#   104,
#   12,
#   422,
#   54,
#   22,
#   1289,
#   230,
#   2,
#   230,
#   371,
#   273,
#   197,
#   81,
#   4,
#   13,
#   162,
#   143,
#   2,
#   104,
#   41,
#   14,
#   36,
#   53,
#   3,
#   15,
#   69,
#   104,
#   355,
#   147,
#   12,
#   2,
#   207,
#   426,
#   166,
#   4,
#   2,
#   169,
#   2064,
#   5,
#   54,
#   22,
#   431,
#   3187,
#   779,
#   5,
#   15,
#   67,
#   35,
#   37,
#   973,
#   3,
#   15,
#   72,
#   3187,
#   779,
#   319,
#   147,
#   5,
#   15,
#   246,
#   58,
#   259,
#   1562,
#   153,
#   5,
#   3,
#   110,
#   15,
#   14,
#   1160,
#   7,
#   650,
#   3187,
#   779,
#   41,
#   69,
#   20,
#   34,
#   8816,
#   434,
#   50,
#   3,
#   15,
#   224,
#   21,
#   7,
#   330,
#   461,
#   86,
#   9,
#   18,
#   163,
#   2,
#   54,
#   473,
#   350,
#   2,
#   54,
#   2415,
#   2,
#   104,
#   41,
#   36,
#   4,
#   422,
#   693,
#   54,
#   319,
#   147,
#   5,
#   1051,
#   2524,
#   531,
#   252,
#   4,
#   403,
#   79,
#   283,
#   2,
#   104,
#   256,
#   422,
#   54,
#   59,
#   393,
#   9,
#   13,
#   330,
#   86,
#   9,
#   6381,
#   196,
#   20,
#   1549,
#   24,
#   7,
#   1198,
#   585,
#   7448,
#   5,
#   14,
#   24,
#   5,
#   642,
#   15,
#   73,
#   1051,
#   531,
#   10,
#   2,
#   112,
#   1,
#   147,
#   21,
#   6381,
#   5,
#   366,
#   270,
#   12,
#   4233,
#   640,
#   18,
#   80,
#   14,
#   1864,
#   2,
#   104,
#   1050,
#   6381,
#   1969,
#   2,
#   124,
#   8,
#   2,
#   1198,
#   585,
#   7448,
#   6381,
#   1014,
#   4,
#   321,
#   20,
#   2,
#   124,
#   8,
#   2,
#   7448,
#   46,
#   13,
#   68,
#   3,
#   15,
#   38,
#   650,
#   5,
#   3,
#   522,
#   172,
#   283,
#   6,
#   104,
#   256],
#  [49,
#   92,
#   76,
#   21,
#   524,
#   4,
#   1090,
#   53,
#   19,
#   76,
#   390,
#   254,
#   772,
#   43,
#   33,
#   616,
#   76,
#   364,
#   4,
#   694,
#   2,
#   49,
#   33,
#   469,
#   2,
#   227,
#   2387,
#   125,
#   7,
#   195,
#   9,
#   1050,
#   2,
#   70,
#   230,
#   2157,
#   81,
#   75,
#   537,
#   8,
#   2,
#   232,
#   508,
#   2,
#   998,
#   8,
#   2,
# ...
#   257,
#   55,
#   4,
#   145,
#   144,
#   8,
#   2,
#   262,
#   3,
#   346,
#   4,
#   400,
#   13,
#   49,
#   5,
#   2,
#   93,
#   8,
#   2,
#   49,
#   3786,
#   4,
#   20,
#   13,
#   17,
#   6,
#   798,
#   622,
#   4,
#   15,
#   2,
#   16,
#   297,
#   400,
#   144,
#   2,
#   49,
#   1526,
#   4,
#   20,
#   18,
#   15,
#   35,
#   7,
#   488,
#   8,
#   813,
#   81,
#   4,
#   400,
#   144,
#   2,
#   49,
#   17,
#   675,
#   13,
#   17,
#   6,
#   798,
#   622,
#   231,
#   674,
#   44,
#   301,
#   16,
#   137,
#   4,
#   310,
#   328,
#   19,
#   471,
#   42,
#   3,
#   547,
#   6,
#   95,
#   263,
#   21,
#   44,
#   301,
#   16,
#   137,
#   10,
#   66,
#   1249,
#   2,
#   30,
#   2,
#   103,
#   8,
#   2,
#   207,
#   620,
#   11,
#   10,
#   6,
#   207,
#   178,
#   103,
#   21,
#   11,
#   12,
#   13,
#   45,
#   142,
#   2,
#   22,
#   174,
#   225,
#   436,
#   154,
#   535,
#   44,
#   301,
#   16,
#   137,
#   31,
#   14,
#   42,
#   2,
#   169,
#   30,
#   540,
#   2,
#   30,
#   17,
#   14,
#   344,
#   5,
#   99,
#   4,
#   103],
#  [143,
#   3,
#   503,
#   6,
#   16,
#   193,
#   256,
#   472,
#   1472,
#   66,
#   3,
#   993,
#   165,
#   23,
#   23,
#   778,
#   9,
#   3,
#   35,
#   7,
#   670,
#   22,
#   21,
#   1479,
#   54,
#   4318,
#   1932,
#   75,
#   3,
#   138,
#   2,
#   55,
#   5,
#   773,
#   3,
#   35,
#   521,
#   2,
#   191,
#   1410,
#   3,
#   35,
#   36,
#   294,
#   203,
#   648,
#   5,
#   236,
#   4183,
#   19,
#   34,
#   12,
#   3,
#   858,
#   13,
#   330,
#   11,
#   971,
#   123,
#   3,
#   35,
#   14,
#   2559,
#   2,
#   1664,
#   2,
#   55,
#   101,
#   18,
#   45,
#   28,
#   23,
#   25,
#   158,
#   5,
#   570,
#   45,
#   27,
#   383,
#   568,
#   8,
#   2,
#   55,
#   187,
#   23,
#   45,
#   226,
#   1554,
#   4,
#   548,
#   81,
#   4,
#   1365,
#   2,
#   223,
#   9,
#   62,
#   87,
#   79,
#   8,
#   2,
#   1664,
#   5,
#   398,
#   6,
#   16,
#   193,
#   203,
#   166,
#   296,
#   6,
#   16,
#   193,
#   11,
#   110,
#   32,
#   975,
#   1203,
#   729,
#   613,
#   599,
#   934,
#   5,
#   2,
#   22,
#   433,
#   4,
#   3689,
#   181,
#   66,
#   3,
#   72,
#   84,
#   2,
#   55,
#   101,
#   23,
#   45,
#   111,
#   226,
#   7,
#   483,
#   174,
#   517,
#   4,
#   645,
#   119,
#   6,
#   16,
#   193,
#   5,
#   1365,
#   2,
#   223,
#   7013,
#   754,
#   4,
#   5,
#   6,
#   16,
#   193,
#   17,
#   110,
#   98,
#   796,
#   5,
#   107,
#   1479,
#   17,
#   380,
#   3,
#   307,
#   105,
#   1010,
#   26,
#   3,
#   15,
#   138,
#   2,
#   55,
#   319,
#   147,
#   1136,
#   4,
#   355,
#   2079,
#   5,
#   5403,
#   5,
#   2,
#   55,
#   41,
#   14,
#   636,
#   284],
#  [70,
#   139,
#   13,
#   17,
#   7,
#   139,
#   277,
#   2,
#   1738,
#   8,
#   34,
#   32,
#   1666,
#   2357,
#   163,
#   21,
#   6,
#   269,
#   1170,
#   1187,
#   16,
#   57,
#   41,
#   34,
#   32,
#   1666,
#   2357,
#   1357,
#   1,
#   33,
#   2,
#   1,
#   10,
#   6,
#   1,
#   256,
#   79,
#   65,
#   2,
#   1,
#   264,
#   14,
#   6400,
#   2491,
#   7892,
#   58,
#   1,
#   19,
#   125,
#   154,
#   269,
#   5,
#   32,
#   6959,
#   2,
#   2357,
#   33,
#   167,
#   275,
#   388,
#   6,
#   32,
#   1666,
#   2357,
#   163,
#   958,
#   4,
#   100,
#   19,
#   7,
#   675,
#   163,
#   3,
#   311,
#   44,
#   8,
#   2,
#   678,
#   259,
#   163,
#   514,
#   1,
#   537,
#   269,
#   1170,
#   16,
#   57,
#   195,
#   161,
#   5,
#   2191,
#   537,
#   19,
#   7,
#   1,
#   46,
#   3,
#   11,
#   190,
#   230,
#   2,
#   548,
#   81,
#   232,
#   8,
#   42,
#   2,
#   3831,
#   1,
#   4,
#   10,
#   2,
#   103,
#   8,
#   823,
#   11,
#   44,
#   268,
#   11,
#   1979,
#   230,
#   734,
#   81,
#   10,
#   2,
#   1,
#   537,
#   390,
#   9,
#   2,
#   1,
#   41,
#   7,
#   125,
#   275,
#   2191,
#   2357,
#   5,
#   496,
#   113,
#   269,
#   19,
#   2,
#   16,
#   57,
#   294,
#   2,
#   161,
#   32,
#   4497,
#   9,
#   264,
#   14,
#   1351,
#   1,
#   47,
#   111,
#   1,
#   40,
#   66,
#   129,
#   2357,
#   6,
#   2357,
#   32,
#   1477,
#   10,
#   6,
#   32,
#   1666,
#   2357,
#   4466,
#   4,
#   3,
#   3341,
#   2,
#   1,
#   46,
#   19,
#   3132,
#   26,
#   10,
#   2277,
#   4,
#   2143,
#   399,
#   5,
#   9190,
#   612,
#   14,
#   4,
#   116,
#   269,
#   515,
#   4,
#   172,
#   9,
#   17,
#   14,
#   362,
#   79,
#   19,
#   675,
#   32,
#   1666,
#   2357,
#   399,
#   3,
#   120,
#   9,
#   2715,
#   20,
#   2618,
#   26,
#   19,
#   2,
#   1,
#   9,
#   11,
#   1584,
#   129,
#   58,
#   32,
#   1666,
#   2357,
#   1277,
#   4333,
#   711,
#   5439,
#   4333,
#   29,
#   161,
#   453,
#   32,
#   1666,
#   2357,
#   163,
#   103,
#   8,
#   823,
#   677,
#   103,
#   8,
#   259,
#   163,
#   514,
#   21,
#   163,
#   93,
#   19,
#   1,
#   2618,
#   26,
#   231,
#   1398,
#   361,
#   2605,
#   26,
#   75,
#   361,
#   1441,
#   8,
#   1006,
#   3831,
#   1,
#   12,
#   1,
#   1080,
#   38,
#   6400,
#   2,
#   1,
#   264,
#   14,
#   3186,
#   656,
#   177,
#   1,
#   1,
#   2191,
#   2357,
#   17,
#   125,
#   154,
#   4,
#   32,
#   1666,
#   2357,
#   17,
#   167,
#   275,
#   4,
#   3341,
#   3831,
#   1,
#   46,
#   2734,
#   711,
#   1294,
#   4333,
#   269,
#   1170,
#   1187,
#   16,
#   57,
#   269,
#   1170,
#   1187,
#   16,
#   465,
#   4333,
#   269,
#   453,
#   1918,
#   269,
#   1335],
#  [3,
#   232,
#   6,
#   16,
#   193,
#   2388,
#   33,
#   105,
#   548,
#   599,
#   464,
#   338,
#   6,
#   16,
#   3,
#   1141,
#   9,
#   77,
#   11,
#   324,
#   42,
#   8,
#   7,
#   97,
#   43,
#   12,
#   10,
#   85,
#   8,
#   6,
#   22,
#   3,
#   15,
#   301,
#   52,
#   21,
#   5,
#   3150,
#   10,
#   6,
#   381,
#   77,
#   41,
#   67,
#   36,
#   7,
#   97,
#   43,
#   10,
#   37,
#   8,
#   2,
#   125,
#   52,
#   22,
#   86,
#   22,
#   668,
#   16,
#   57,
#   2366,
#   611,
#   22,
#   349,
#   267,
#   343,
#   43,
#   1059,
#   26,
#   103,
#   152,
#   90,
#   3244,
#   26,
#   565,
#   2763,
#   26,
#   239,
#   83,
#   371,
#   26,
#   43,
#   349,
#   91,
#   29,
#   362,
#   25,
#   495,
#   16,
#   57],
#  [194,
#   69,
#   7,
#   76,
#   566,
#   143,
#   958,
#   4,
#   882,
#   21,
#   2,
#   229,
#   171,
#   3136,
#   415,
#   314,
#   13,
#   17,
#   7,
#   1616,
#   5,
#   672,
#   288,
#   8,
#   2,
#   229,
#   709,
#   3,
#   48,
#   1352,
#   159,
#   24,
#   2,
#   386,
#   12,
#   13,
#   245],
#  [12,
#   143,
#   3,
#   656,
#   34,
#   2487,
#   2201,
#   12,
#   2,
#   93,
#   8,
#   1145,
#   26,
#   4,
#   27,
#   383,
#   12,
#   143,
#   24,
#   34,
#   259,
#   1995,
#   19,
#   7,
#   576,
#   585,
#   1634,
#   1995,
#   12,
#   2,
#   5004,
#   8,
#   639,
#   411,
#   44,
#   5799,
#   62,
#   1242,
#   33,
#   3993,
#   19,
#   6,
#   32,
#   1508,
#   68,
#   8,
#   1634,
#   5,
#   3993,
#   1069,
#   9191,
#   58,
#   104,
#   584,
#   3,
#   573,
#   79,
#   4,
#   19,
#   7,
#   407,
#   10,
#   7,
#   153,
#   9,
#   118,
#   14,
#   27,
#   3365,
#   41,
#   843,
#   9,
#   2,
#   576,
#   585,
#   1995,
#   17,
#   654,
#   19,
#   13,
#   5,
#   18,
#   80,
#   14,
#   944,
#   20,
#   12,
#   792,
#   7,
#   407,
#   2,
#   576,
#   585,
#   1995,
#   41,
#   375,
#   4,
#   145,
#   7,
#   407,
#   2,
#   576,
#   585,
#   1740,
#   375,
#   4,
#   145,
#   7,
#   407,
#   1256,
#   9,
#   18,
#   53,
#   7,
#   407,
#   19,
#   44,
#   2113,
#   5,
#   2025,
#   6177,
#   9,
#   62,
#   87,
#   12,
#   1222,
#   3,
#   48,
#   498,
#   9,
#   2,
#   425,
#   208,
#   272,
#   8,
#   3962,
#   644,
#   7,
#   232,
#   12,
#   143,
#   1841,
#   3993,
#   4,
#   145,
#   2573,
#   25,
#   357,
#   2,
#   425,
#   208,
#   272,
#   8,
#   3962,
#   232,
#   7542,
#   15,
#   7,
#   1,
#   853,
#   4,
#   145,
#   7,
#   2343,
#   407,
#   4,
#   7,
#   1,
#   6739,
#   66,
#   2,
#   3400,
#   1,
#   2,
#   9191,
#   2113,
#   29,
#   1080,
#   7,
#   1942,
#   516,
#   12,
#   2,
#   2113,
#   1681,
#   5,
#   2,
#   6739,
#   5685,
#   14,
#   4,
#   762,
#   2,
#   3599,
#   730,
#   33,
#   2,
#   3400,
#   113,
#   3,
#   11,
#   59,
#   33,
#   9,
#   13,
#   264,
#   14,
#   542,
#   4,
#   58,
#   7363,
#   7182,
#   899,
#   18,
#   31,
#   593,
#   12,
#   164,
#   2424,
#   540,
#   3,
#   219,
#   13,
#   21,
#   6,
#   16,
#   57,
#   55,
#   132,
#   187,
#   9,
#   18,
#   63,
#   14,
#   15,
#   664,
#   418,
#   123,
#   13,
#   153,
#   11,
#   1113,
#   141,
#   7,
#   576,
#   585,
#   1995,
#   3,
#   80,
#   14,
#   15,
#   7,
#   55,
#   366,
#   6,
#   104,
#   329,
#   13,
#   68,
#   8,
#   3165,
#   880,
#   19,
#   7,
#   153,
#   9,
#   11,
#   14,
#   1796,
#   4,
#   367,
#   13,
#   191,
#   3,
#   160,
#   7,
#   198,
#   407,
#   19,
#   7,
#   153,
#   9,
#   3,
#   80,
#   14,
#   322,
#   83,
#   4,
#   34,
#   6401,
#   2473,
#   807],
#  [3,
#   48,
#   394,
#   4,
#   145,
#   7,
#   139,
#   9,
#   11,
#   1117,
#   10,
#   6,
#   16,
#   116,
#   10,
#   797,
#   8,
#   261,
#   22,
#   86,
#   2,
#   356,
#   751,
#   17,
#   184,
#   1019,
#   71,
#   167,
#   3,
#   67,
#   53,
#   37,
#   1224,
#   591,
#   9,
#   8,
#   2434,
#   37,
#   1809,
#   4,
#   13,
#   210,
#   5,
#   540,
#   14,
#   654,
#   19,
#   13,
#   49,
#   5,
#   122,
#   15,
#   14,
#   36,
#   130,
#   12,
#   6,
#   16,
#   116,
#   117,
#   13,
#   22,
#   11,
#   2926,
#   478,
#   2982,
#   33,
#   10,
#   3,
#   503,
#   13,
#   49,
#   35,
#   36,
#   449,
#   10,
#   6,
#   16,
#   28,
#   25,
#   408,
#   34,
#   152,
#   103,
#   8,
#   151,
#   21,
#   349,
#   574,
#   239,
#   83,
#   25,
#   8,
#   151,
#   478,
#   2982,
#   13,
#   22,
#   4,
#   1133,
#   25,
#   7,
#   164,
#   49,
#   1359,
#   102,
#   1599,
#   33,
#   7,
#   164,
#   210,
#   370,
#   17,
#   1754,
#   8,
#   76,
#   69,
#   4,
#   210,
#   10,
#   3,
#   503,
#   13,
#   49,
#   35,
#   36,
#   449,
#   10,
#   6,
#   16,
#   28,
#   3,
#   48,
#   664,
#   2,
#   476,
#   1844,
#   49,
#   89,
#   299,
#   13,
#   49,
#   25,
#   340,
#   33,
#   2,
#   212,
#   49,
#   92,
#   387,
#   706,
#   171,
#   1952,
#   5,
#   1,
#   70,
#   92,
#   387,
#   157,
#   1,
#   2724,
#   1420,
#   1583,
#   44,
#   49,
#   1679,
#   4,
#   199,
#   961,
#   405,
#   268,
#   1311,
#   2,
#   49,
#   5783,
#   135,
#   4300,
#   1420,
#   129,
#   171,
#   1,
#   8,
#   2,
#   1390,
#   6178,
#   8,
#   2,
#   1220,
#   70,
#   92,
#   387,
#   157,
#   325,
#   1156,
#   44,
#   2,
#   227,
#   144,
#   8,
#   6,
#   359,
#   4,
#   100,
#   2,
#   177,
#   210,
#   7,
#   209,
#   8,
#   2,
#   798,
#   22,
#   195,
#   644,
#   33,
#   2,
#   177,
#   210,
#   7,
#   2853,
#   8,
#   2,
#   488,
#   93,
#   83,
#   298,
#   737,
#   181,
#   5,
#   135,
#   223,
#   5,
#   19,
#   44,
#   135,
#   223,
#   2,
#   103,
#   8,
#   5,
#   2,
#   1165,
#   19,
#   257,
#   170,
#   145,
#   144,
#   9,
#   2,
#   310,
#   8,
#   1354,
#   41,
#   14,
#   32,
#   1477,
#   10,
#   2,
#   306,
#   49,
#   29,
#   145,
#   144,
#   9,
#   2,
#   306,
#   49,
#   22,
#   41,
#   14,
#   27,
#   478,
#   2982,
#   25,
#   7,
#   396,
#   8,
#   5075,
#   387,
#   3,
#   95,
#   13,
#   170,
#   71,
#   3,
#   63,
#   14,
#   1131,
#   13,
#   49,
#   5,
#   3,
#   63,
#   14,
#   307,
#   37,
#   104,
#   4,
#   13,
#   210,
#   71,
#   3,
#   48,
#   664,
#   13,
#   49,
#   39,
#   122,
#   14,
#   28,
#   23,
#   4,
#   2,
#   16,
#   42,
#   280,
#   64,
#   39,
#   15,
#   320,
#   130,
#   23,
#   89,
#   783,
#   2,
#   16,
#   42,
#   280,
#   9,
#   2,
#   49,
#   17,
#   219,
#   5,
#   29,
#   414,
#   2,
#   816,
#   391,
#   24,
#   6,
#   16,
#   28,
#   42,
#   30,
#   9,
#   39,
#   172,
#   4,
#   27,
#   184,
#   29,
#   1884,
#   4,
#   28,
#   30,
#   940,
#   2099,
#   2,
#   1,
#   5,
#   58,
#   212,
#   16,
#   42,
#   157],
#  [89,
#   133,
#   24,
#   6,
#   22,
#   19,
#   846,
#   5,
#   184,
#   184,
#   8,
#   267,
#   162,
#   184,
#   8,
#   43,
#   381,
#   184,
#   90,
#   13,
#   17,
#   7,
#   288],
#  [3,
#   661,
#   4,
#   88,
#   6,
#   16,
#   736,
#   83,
#   4,
#   7,
#   834,
#   8,
#   615,
#   3,
#   638,
#   4,
#   221,
#   12,
#   2,
#   206,
#   3,
#   15,
#   67,
#   688,
#   24,
#   2,
#   452,
#   231,
#   540,
#   3,
#   2441,
#   115,
#   134,
#   66,
#   3,
#   748,
#   6,
#   28,
#   3,
#   11,
#   1732,
#   33,
#   1800,
#   10,
#   7,
#   834,
#   8,
#   621,
#   9,
#   3,
#   15,
#   67,
#   152,
#   12,
#   6,
#   660,
#   2,
#   621,
#   253,
#   10,
#   6,
#   1451,
#   31,
#   14,
#   276,
#   89,
#   133,
#   61,
#   689,
#   202,
#   24,
#   6,
#   28,
#   1429,
#   26,
#   1111,
#   26,
#   681,
#   26,
#   3818,
#   26],
#  [3,
#   15,
#   69,
#   319,
#   508,
#   4,
#   265,
#   5,
#   32,
#   192,
#   12,
#   50,
#   5,
#   31,
#   42,
#   1782,
#   52,
#   21,
#   336,
#   267,
#   571,
#   5,
#   947,
#   50,
#   17,
#   1472,
#   1252,
#   6,
#   16,
#   381,
#   61,
#   52,
#   62,
#   219,
#   5,
#   73,
#   724,
#   8,
#   2,
#   16,
#   28,
#   62,
#   69,
#   165,
#   4,
#   40,
#   25,
#   190,
#   3,
#   128,
#   40,
#   19,
#   144,
#   9,
#   2,
#   55,
#   127,
#   602,
#   4,
#   40,
#   5,
#   19,
#   144,
#   8,
#   109,
#   11,
#   246,
#   4,
#   1341,
#   13,
#   30,
#   11,
#   295,
#   25,
#   344,
#   5,
#   3,
#   15,
#   255,
#   4,
#   88,
#   9,
#   30,
#   32,
#   192,
#   815,
#   4,
#   28,
#   184,
#   1304,
#   30,
#   25,
#   190],
#  [718,
#   6,
#   188,
#   4,
#   3276,
#   9589,
#   12,
#   46,
#   9,
#   68,
#   11,
#   21,
#   108,
#   2906,
#   6,
#   108,
#   11,
#   509,
#   4,
#   4,
#   50,
#   3,
#   11,
#   67,
#   138,
#   94,
#   5,
#   3,
#   15,
#   36,
#   252,
#   4,
#   88,
#   6,
#   104,
#   4,
#   398,
#   6,
#   520,
#   24,
#   40,
#   65,
#   75,
#   4691,
#   6,
#   68,
#   677,
#   399,
#   21,
#   19,
#   176,
#   166,
#   3,
#   403,
#   79,
#   141,
#   40,
#   9,
#   6,
#   108,
#   41,
#   36,
#   509,
#   4,
#   2199,
#   2199,
#   843,
#   44,
#   3,
#   365,
#   11,
#   7,
#   798,
#   1778,
#   4,
#   221,
#   2849,
#   613,
#   8,
#   6,
#   104,
#   428,
#   20,
#   34,
#   7766,
#   86,
#   4,
#   178,
#   117,
#   273,
#   517,
#   427,
#   5,
#   240,
#   67,
#   247,
#   84,
#   4,
#   20,
#   29,
#   6,
#   2695,
#   4,
#   560,
#   99,
#   2539,
#   75,
#   561,
#   287,
#   46,
#   696,
#   436,
#   33,
#   575,
#   4498,
#   4,
#   2199,
#   4498,
#   3,
#   403,
#   79,
#   293,
#   9,
#   13,
#   961,
#   4498,
#   41,
#   36,
#   7,
#   395,
#   5,
#   11,
#   4775,
#   180,
#   11,
#   13,
#   67,
#   5616,
#   4,
#   20,
#   329,
#   6,
#   561,
#   3151,
#   21,
#   2199,
#   176,
#   147,
#   2199,
#   59,
#   575,
#   6,
#   2695,
#   9,
#   60,
#   45,
#   27,
#   138,
#   230,
#   1039,
#   531,
#   33,
#   34,
#   4498,
#   9,
#   67,
#   562,
#   2,
#   207,
#   98,
#   117,
#   81,
#   427,
#   2199,
#   41,
#   14,
#   237,
#   4,
#   1888,
#   6,
#   439,
#   379,
#   3,
#   15,
#   1,
#   2695,
#   4,
#   100,
#   19,
#   318,
#   2837,
#   5,
#   1,
#   188,
#   12,
#   50,
#   3,
#   15,
#   36,
#   8013,
#   24,
#   123,
#   3,
#   48,
#   46,
#   6,
#   5885,
#   437,
#   5,
#   48,
#   2168,
#   8,
#   98,
#   383,
#   19,
#   7,
#   7034,
#   3,
#   160,
#   6,
#   104,
#   6,
#   188,
#   317,
#   84,
#   1916,
#   23,
#   17,
#   14,
#   6,
#   1066,
#   9,
#   13,
#   55,
#   80,
#   14,
#   88,
#   34,
#   4498,
#   79,
#   4,
#   6,
#   417,
#   12,
#   7,
#   814,
#   906,
#   23,
#   17,
#   2,
#   309,
#   1066,
#   13,
#   17,
#   6,
#   104,
#   4,
#   50,
#   3,
#   160,
#   107,
#   65,
#   3,
#   80,
#   88,
#   84,
#   165,
#   6,
#   188,
#   89,
#   159,
#   20,
#   1,
#   568,
#   8,
#   13,
#   439,
#   440,
#   39],
#  [77,
#   17,
#   34,
#   3372,
#   149,
#   253,
#   21,
#   6,
#   124,
#   10,
#   6,
#   16,
#   28,
#   5,
#   3,
#   15,
#   67,
#   1060,
#   363,
#   48,
#   3,
#   24,
#   9,
#   310,
#   279,
#   246,
#   6,
#   124,
#   5,
#   1207,
#   4,
#   2318,
#   1413],
#  [610,
#   3,
#   48,
#   14,
#   2,
#   240,
#   18,
#   31,
#   851,
#   19,
#   18,
#   67,
#   127,
#   69,
#   20,
#   7,
#   76,
#   183,
#   236,
#   409,
#   2293,
#   88,
#   89,
#   505,
#   40,
#   4,
#   518,
#   467,
#   20],
#  [19,
#   502,
#   154,
#   3,
#   15,
#   4994,
#   36,
#   362,
#   119,
#   7,
#   90,
#   24,
#   2407,
#   26,
#   4,
#   293,
#   2763,
#   26,
#   107,
#   3,
#   128,
#   1231,
#   8,
#   3919,
#   374,
#   4,
#   145,
#   20,
#   812,
#   4,
#   100,
#   5,
#   100,
#   119,
#   2,
#   1015,
#   90,
#   12,
#   671,
#   2513,
#   3,
#   187,
#   1344,
#   317,
#   20,
#   12,
#   392,
#   64,
#   39,
#   673,
#   4,
#   318,
#   21,
#   20,
#   12,
#   382,
#   4,
#   100,
#   119,
#   1015,
#   90,
#   4,
#   893,
#   198,
#   607,
#   5,
#   7893,
#   8,
#   1193],
#  [3,
#   69,
#   313,
#   4,
#   2,
#   137,
#   94,
#   236,
#   184,
#   202,
#   298,
#   10,
#   6,
#   16,
#   28,
#   23,
#   41,
#   36,
#   105,
#   548,
#   81,
#   5,
#   3,
#   15,
#   14,
#   53,
#   7,
#   189,
#   3,
#   15,
#   305,
#   109,
#   3,
#   48,
#   59,
#   48,
#   4832,
#   8,
#   481,
#   25,
#   7,
#   70,
#   47,
#   23,
#   864,
#   183,
#   6,
#   1324,
#   31,
#   5664,
#   5,
#   347,
#   3063,
#   3,
#   534,
#   9,
#   6,
#   1324,
#   27,
#   1581,
#   5,
#   9,
#   61,
#   202,
#   1109,
#   1432,
#   632,
#   12,
#   2,
#   224,
#   313,
#   89,
#   414,
#   2,
#   202,
#   9,
#   15,
#   36,
#   175,
#   4,
#   27,
#   327,
#   5,
#   574,
#   2,
#   202,
#   9,
#   15,
#   36,
#   175,
#   4,
#   27,
#   482,
#   200,
#   3,
#   15,
#   224,
#   6,
#   1539,
#   804,
#   5,
#   7,
#   1905,
#   241,
#   19,
#   325,
#   8,
#   461],
#  [3,
#   547,
#   664,
#   21,
#   2,
#   137,
#   1212,
#   12,
#   3,
#   15,
#   36,
#   1997,
#   664,
#   52,
#   9,
#   38,
#   85,
#   41,
#   416,
#   295,
#   29,
#   1142,
#   19,
#   20,
#   3,
#   15,
#   175,
#   5262,
#   24,
#   2,
#   137,
#   5,
#   590,
#   255,
#   260,
#   41,
#   36,
#   196,
#   75,
#   319,
#   7187,
#   8,
#   508,
#   3,
#   541,
#   214,
#   6,
#   186,
#   139,
#   10,
#   13,
#   110,
#   377,
#   396,
#   12,
#   37,
#   1574,
#   24,
#   2,
#   137,
#   428,
#   23,
#   7,
#   483,
#   174,
#   7187,
#   8,
#   508,
#   5,
#   214,
#   204,
#   139,
#   10,
#   255,
#   121,
#   260,
#   24,
#   546,
#   13,
#   17,
#   6,
#   576,
#   139,
#   66,
#   74,
#   2,
#   137,
#   541,
#   27,
#   845,
#   1643,
#   19,
#   58,
#   776,
#   29,
#   1062,
#   8,
#   776,
#   13,
#   41,
#   36,
#   2029,
#   19,
#   167,
#   273,
#   154],
#  [6,
#   124,
#   17,
#   110,
#   14,
#   250,
#   21,
#   44,
#   125,
#   16,
#   137,
#   1247,
#   194,
#   5,
#   594,
#   6,
#   124,
#   12,
#   198,
#   47,
#   56,
#   14,
#   953,
#   25,
#   7,
#   9366,
#   6,
#   186,
#   124,
#   17,
#   1635,
#   17,
#   207,
#   29,
#   2375,
#   124,
#   17,
#   6,
#   9366,
#   17,
#   29,
#   540,
#   6,
#   124,
#   122,
#   1038,
#   73,
#   329,
#   13,
#   825,
#   115,
#   134,
#   39,
#   589,
#   236,
#   30,
#   4678,
#   391,
#   8,
#   16,
#   17,
#   111,
#   298,
#   99,
#   10,
#   14,
#   10,
#   194,
#   29,
#   932,
#   16,
#   57,
#   17,
#   111,
#   298,
#   99,
#   10,
#   14,
#   10,
#   194,
#   29,
#   73,
#   82,
#   309,
#   589,
#   6,
#   470,
#   51,
#   24,
#   11,
#   42,
#   13,
#   47,
#   23,
#   256,
#   119,
#   329,
#   2,
#   115,
#   134,
#   220,
#   13,
#   470,
#   51,
#   11,
#   14,
#   34,
#   191,
#   13,
#   11,
#   250,
#   2,
#   16,
#   57,
#   21,
#   2,
#   169,
#   55,
#   11,
#   226,
#   119,
#   285,
#   19,
#   2,
#   207,
#   68,
#   110,
#   10,
#   563],
#  [3,
#   11,
#   138,
#   12,
#   33,
#   7,
#   49,
#   628,
#   5,
#   87,
#   498,
#   8,
#   7,
#   51,
#   873,
#   152,
#   21,
#   6,
#   115,
#   21,
#   7,
#   3224,
#   1243,
#   12,
#   966,
#   12,
#   3,
#   56,
#   14,
#   15,
#   1771,
#   16,
#   4,
#   557,
#   7,
#   51,
#   46,
#   9,
#   68,
#   3,
#   63,
#   14,
#   559,
#   155,
#   279,
#   656,
#   7,
#   492,
#   182,
#   663,
#   1137,
#   29,
#   268,
#   215,
#   25,
#   413,
#   323,
#   57,
#   1033,
#   100,
#   3996,
#   775,
#   3,
#   214,
#   7,
#   385,
#   28,
#   5,
#   15,
#   237,
#   561,
#   147,
#   4,
#   88,
#   30,
#   10,
#   132,
#   2,
#   5099,
#   11,
#   5,
#   132,
#   2,
#   558,
#   1074,
#   11,
#   9,
#   536,
#   13,
#   51,
#   182,
#   663,
#   1137,
#   21,
#   38,
#   2203,
#   2,
#   1243,
#   74,
#   38,
#   3953,
#   363,
#   321,
#   6,
#   37,
#   598,
#   29,
#   528,
#   6,
#   287],
#  [11,
#   91,
#   141,
#   2,
#   92,
#   136,
#   10,
#   151,
#   19,
#   681,
#   26,
#   23,
#   11,
#   495,
#   9,
#   13,
#   22,
#   45,
#   27,
#   327,
#   24,
#   6,
#   16,
#   28,
#   3,
#   15,
#   196,
#   9,
#   30,
#   4,
#   5,
#   289,
#   47,
#   110,
#   211,
#   9,
#   3,
#   307,
#   40],
#  ...]

# %% [markdown]
# ### Padding

# %% [markdown]
# * when using the keras embedding layer, (actually any neural network layer), we always must input data of the same dimensions
#
# * **problem:** sentences are often of different length
#
# * **solution:** select a max length for the sentences and make sure that all sentences are of that length
#     * if a sentence is longer, truncate it
#     * if a sentence is shorter, pad it with zeroes

# %% [markdown]
# * always pad all data (training, validation and testing data)

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
max_len_of_sequence = max(len(x) for x in X_train)

print(max_len_of_sequence)
# Out:
# 5277

# %%
# Define values important for padding

max_length = 100
trunc_type = "post"
padding_type = "post"

# %%
all_len = [len(x) for x in X_train]
len(X_train[np.argmax(all_len)])
# Out:
# 5277

# %%
# Pad train, validation and test data

X_train = pad_sequences(X_train, padding=padding_type, maxlen=max_length, truncating=trunc_type)
X_valid = pad_sequences(X_valid, padding=padding_type, maxlen=max_length, truncating=trunc_type)
X_test = pad_sequences(X_test, padding=padding_type, maxlen=max_length, truncating=trunc_type)

# %% [markdown]
# ### Model creation

# %% [markdown]
# * don't worry about this part: we'll cover it in detail in just a bit

# %% [markdown]
# * for now, you only need to understand the embedding layer:
#
#     * as the **input_dim** argument use the size of your vocabulary + 1
#     * as the **output_dim** use how many vectors do you want to use to embed your words
#     * as **max_length** use the number of words you limited your sentences to

# %%
len(tokenizer.word_index)
# Out:
# 45124

# %%
from keras.layers import Embedding, Dense, LSTM, Dropout
from keras.models import Sequential

embedding_dim = 100
input_dim = len(tokenizer.word_index) + 1

model = Sequential()
model.add(Embedding(input_dim=input_dim, output_dim=embedding_dim, input_length=max_length))
model.add(LSTM(32, recurrent_dropout=0.2)) 
model.add(Dense(16, activation="relu"))
model.add(Dense(y.nunique(), activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          4512500
#
#  lstm (LSTM)                 (None, 32)                17024
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 17)                289
#
# =================================================================
# Total params: 4,530,341
# Trainable params: 4,530,341
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model compiling and training

# %%
from tensorflow.keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
from keras.metrics import SparseCategoricalAccuracy

loss_function = SparseCategoricalCrossentropy()

metric = SparseCategoricalAccuracy()

optim = Adam()

model.compile(loss=loss_function, optimizer=optim, metrics=["accuracy"])

# %%
num_epochs = 10

batch_size = 128

history = model.fit(X_train, 
                    y_train, 
                    batch_size=batch_size, 
                    epochs=num_epochs, 
                    verbose=1, 
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 45s 68ms/step - loss: 1.4294 - accuracy: 0.5393 - val_loss: 1.1809 - val_accuracy: 0.5982
# Epoch 2/10
# 625/625 [==============================] - 43s 68ms/step - loss: 1.0729 - accuracy: 0.6439 - val_loss: 0.9365 - val_accuracy: 0.6956
# Epoch 3/10
# 625/625 [==============================] - 42s 67ms/step - loss: 0.7597 - accuracy: 0.7613 - val_loss: 0.6929 - val_accuracy: 0.7754
# Epoch 4/10
# 625/625 [==============================] - 42s 67ms/step - loss: 0.6081 - accuracy: 0.8022 - val_loss: 0.6126 - val_accuracy: 0.7997
# Epoch 5/10
# 625/625 [==============================] - 43s 69ms/step - loss: 0.5206 - accuracy: 0.8358 - val_loss: 0.5807 - val_accuracy: 0.8215
# Epoch 6/10
# 625/625 [==============================] - 43s 69ms/step - loss: 0.4582 - accuracy: 0.8577 - val_loss: 0.5883 - val_accuracy: 0.8229
# Epoch 7/10
# 625/625 [==============================] - 43s 69ms/step - loss: 0.4063 - accuracy: 0.8762 - val_loss: 0.5926 - val_accuracy: 0.8237
# Epoch 8/10
# 625/625 [==============================] - 44s 70ms/step - loss: 0.3630 - accuracy: 0.8895 - val_loss: 0.6061 - val_accuracy: 0.8178
# Epoch 9/10
# 625/625 [==============================] - 44s 71ms/step - loss: 0.3270 - accuracy: 0.9014 - val_loss: 0.6341 - val_accuracy: 0.8186
# Epoch 10/10
# 625/625 [==============================] - 43s 69ms/step - loss: 0.2925 - accuracy: 0.9130 - val_loss: 0.6655 - val_accuracy: 0.8145

# %%
score = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6687 - accuracy: 0.8144

# %%
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Test loss: 0.6687042713165283 / Test accuracy: 0.8143600225448608

# %% [markdown]
# **Problem we typically run into: not enough data !**

# %% [markdown]
# **Solution: use pretrained word vectors**
#
# * we use pretrained vectors from:
#
#     * `spaCy`
#     * `Word2Vec`
#     * `GloVe`

# %% [markdown]
# * using pretrained components in our model is the basis of **transfer learning**
#     * more on transfer learning later

# %% [markdown]
#  <div>
# <img src="https://edlitera-images.s3.amazonaws.com/new_edlitera_logo.png" width="500"/>
# </div>
